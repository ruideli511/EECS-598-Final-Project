# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from typing import Dict, Tuple
import json
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torch.optim as optim
import torch.utils.data
import numpy as np
import torch.optim as optim
import torch.utils.data
import numpy as np

from torch.optim.lr_scheduler import ReduceLROnPlateau


from torchinfo import summary

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # VAE Baseline - Direct Prediction from input string

# %% [markdown]
# ## Data Preprocessing

# %%
def save_dict_json(word2idx: Dict[str, int], filename: str) -> None:
    """
    Save the word2idx dictionary to a JSON file.

    Parameters:
    - word2idx (Dict[str, int]): The word-to-index mapping dictionary.
    - filename (str): The name of the file where the dictionary will be saved.
    """

    with open(filename, "w") as f:
        json.dump(word2idx, f)


def load_dict_json(filename: str) -> Dict[str, int]:
    """
    Load the word2idx dictionary from a JSON file.

    Parameters:
    - filename (str): The name of the file from which the dictionary will be loaded.

    Returns:
    - Dict[str, int]: The loaded word-to-index mapping dictionary.
    """

    with open(filename, "r") as f:
        word2idx = json.load(f)
    return word2idx

# %%
def transform_dict_values(input_dict: dict) -> dict:
    """
    Transforms the values of a dictionary by applying the formula 2 * i + 3,
    where i is the original value.

    Parameters:
    input_dict (dict): A dictionary with integer values.

    Returns:
    dict: A new dictionary with transformed values.
    """
    transformed_dict = {}
    for key, value in input_dict.items():
        # Assuming the values can be converted to integers
        transformed_value = 1 * int(value)
        # + 3
        transformed_dict[key] = transformed_value

    return transformed_dict

# %%
ct2idx = load_dict_json(r"/content/drive/MyDrive/Project_MingyuZhong_Ver.11.10/Project/data/cell_type_word2idx.json")
pert2idx = load_dict_json(r"/content/drive/MyDrive/Project_MingyuZhong_Ver.11.10/Project/data/sm_name_word2idx.json")
print((ct2idx))
print((pert2idx))

ct2idx = transform_dict_values(ct2idx)
pert2idx = transform_dict_values(pert2idx)
print((ct2idx))
print((pert2idx))
# Out:
# {'B cells': 0, 'Myeloid cells': 1, 'NK cells': 2, 'T cells CD4+': 3, 'T cells CD8+': 4, 'T regulatory cells': 5}
# {'5-(9-Isopropyl-8-methyl-2-morpholino-9H-purin-6-yl)pyrimidin-2-amine': 0, 'ABT-199 (GDC-0199)': 1, 'ABT737': 2, 'AMD-070 (hydrochloride)': 3, 'AT 7867': 4, 'AT13387': 5, 'AVL-292': 6, 'AZ628': 7, 'AZD-8330': 8, 'AZD3514': 9, 'AZD4547': 10, 'Alogliptin': 11, 'Alvocidib': 12, 'Amiodarone': 13, 'Atorvastatin': 14, 'Azacitidine': 15, 'BAY 61-3606': 16, 'BAY 87-2243': 17, 'BI-D1870': 18, 'BMS-265246': 19, 'BMS-387032': 20, 'BMS-536924': 21, 'BMS-777607': 22, 'BX 912': 23, 'Belinostat': 24, 'Bosutinib': 25, 'Buspirone': 26, 'CC-401': 27, 'CEP-18770 (Delanzomib)': 28, 'CEP-37440': 29, 'CGM-097': 30, 'CGP 60474': 31, 'CHIR-99021': 32, 'Cabozantinib': 33, 'Canertinib': 34, 'Ceritinib': 35, 'Chlorpheniramine': 36, 'Clemastine': 37, 'Clomipramine': 38, 'Clotrimazole': 39, 'Colchicine': 40, 'Colforsin': 41, 'Crizotinib': 42, 'Dabrafenib': 43, 'Dactolisib': 44, 'Dasatinib': 45, 'Decitabine': 46, 'Defactinib': 47, 'Desloratadine': 48, 'Disulfiram': 49, 'Dovitinib': 50, 'Doxorubicin': 51, 'FK 866': 52, 'Flutamide': 53, 'Foretinib': 54, 'GLPG0634': 55, 'GO-6976': 56, 'GSK-1070916': 57, 'GSK256066': 58, 'GW843682X': 59, 'Ganetespib (STA-9090)': 60, 'HMN-214': 61, 'HYDROXYUREA': 62, 'I-BET151': 63, 'IKK Inhibitor VII': 64, 'IMD-0354': 65, 'IN1451': 66, 'Idelalisib': 67, 'Imatinib': 68, 'Isoniazid': 69, 'Ixabepilone': 70, 'K-02288': 71, 'Ketoconazole': 72, 'LDN 193189': 73, 'LY2090314': 74, 'Lamivudine': 75, 'Lapatinib': 76, 'Linagliptin': 77, 'MGCD-265': 78, 'MK-5108': 79, 'MLN 2238': 80, 'Masitinib': 81, 'Methotrexate': 82, 'Midostaurin': 83, 'Mometasone Furoate': 84, 'Mubritinib (TAK 165)': 85, 'Navitoclax': 86, 'Nefazodone': 87, 'Nilotinib': 88, 'O-Demethylated Adapalene': 89, 'OSI-930': 90, 'Oprozomib (ONX 0912)': 91, 'Oxybenzone': 92, 'PD-0325901': 93, 'PF-03814735': 94, 'PF-04691502': 95, 'PRT-062607': 96, 'Palbociclib': 97, 'Penfluridol': 98, 'Perhexiline': 99, 'Phenylbutazone': 100, 'Pitavastatin Calcium': 101, 'Pomalidomide': 102, 'Porcn Inhibitor III': 103, 'Prednisolone': 104, 'Proscillaridin A;Proscillaridin-A': 105, 'Protriptyline': 106, 'Quizartinib': 107, 'R428': 108, 'RG7090': 109, 'RG7112': 110, 'RN-486': 111, 'RVX-208': 112, 'Raloxifene': 113, 'Resminostat': 114, 'Ricolinostat': 115, 'Riociguat': 116, 'Ruxolitinib': 117, 'SB525334': 118, 'SCH-58261': 119, 'SLx-2119': 120, 'STK219801': 121, 'Saracatinib': 122, 'Scriptaid': 123, 'Selumetinib': 124, 'Sgc-cbp30': 125, 'Sunitinib': 126, 'TGX 221': 127, 'TIE2 Kinase Inhibitor': 128, 'TL_HRAS26': 129, 'TPCA-1': 130, 'TR-14035': 131, 'Tacalcitol': 132, 'Tamatinib': 133, 'Tipifarnib': 134, 'Tivantinib': 135, 'Tivozanib': 136, 'Topotecan': 137, 'Tosedostat': 138, 'Trametinib': 139, 'UNII-BXU45ZH6LI': 140, 'Vandetanib': 141, 'Vanoxerine': 142, 'Vardenafil': 143, 'Vorinostat': 144, 'YK 4-279': 145}
# {'B cells': 0, 'Myeloid cells': 1, 'NK cells': 2, 'T cells CD4+': 3, 'T cells CD8+': 4, 'T regulatory cells': 5}
# {'5-(9-Isopropyl-8-methyl-2-morpholino-9H-purin-6-yl)pyrimidin-2-amine': 0, 'ABT-199 (GDC-0199)': 1, 'ABT737': 2, 'AMD-070 (hydrochloride)': 3, 'AT 7867': 4, 'AT13387': 5, 'AVL-292': 6, 'AZ628': 7, 'AZD-8330': 8, 'AZD3514': 9, 'AZD4547': 10, 'Alogliptin': 11, 'Alvocidib': 12, 'Amiodarone': 13, 'Atorvastatin': 14, 'Azacitidine': 15, 'BAY 61-3606': 16, 'BAY 87-2243': 17, 'BI-D1870': 18, 'BMS-265246': 19, 'BMS-387032': 20, 'BMS-536924': 21, 'BMS-777607': 22, 'BX 912': 23, 'Belinostat': 24, 'Bosutinib': 25, 'Buspirone': 26, 'CC-401': 27, 'CEP-18770 (Delanzomib)': 28, 'CEP-37440': 29, 'CGM-097': 30, 'CGP 60474': 31, 'CHIR-99021': 32, 'Cabozantinib': 33, 'Canertinib': 34, 'Ceritinib': 35, 'Chlorpheniramine': 36, 'Clemastine': 37, 'Clomipramine': 38, 'Clotrimazole': 39, 'Colchicine': 40, 'Colforsin': 41, 'Crizotinib': 42, 'Dabrafenib': 43, 'Dactolisib': 44, 'Dasatinib': 45, 'Decitabine': 46, 'Defactinib': 47, 'Desloratadine': 48, 'Disulfiram': 49, 'Dovitinib': 50, 'Doxorubicin': 51, 'FK 866': 52, 'Flutamide': 53, 'Foretinib': 54, 'GLPG0634': 55, 'GO-6976': 56, 'GSK-1070916': 57, 'GSK256066': 58, 'GW843682X': 59, 'Ganetespib (STA-9090)': 60, 'HMN-214': 61, 'HYDROXYUREA': 62, 'I-BET151': 63, 'IKK Inhibitor VII': 64, 'IMD-0354': 65, 'IN1451': 66, 'Idelalisib': 67, 'Imatinib': 68, 'Isoniazid': 69, 'Ixabepilone': 70, 'K-02288': 71, 'Ketoconazole': 72, 'LDN 193189': 73, 'LY2090314': 74, 'Lamivudine': 75, 'Lapatinib': 76, 'Linagliptin': 77, 'MGCD-265': 78, 'MK-5108': 79, 'MLN 2238': 80, 'Masitinib': 81, 'Methotrexate': 82, 'Midostaurin': 83, 'Mometasone Furoate': 84, 'Mubritinib (TAK 165)': 85, 'Navitoclax': 86, 'Nefazodone': 87, 'Nilotinib': 88, 'O-Demethylated Adapalene': 89, 'OSI-930': 90, 'Oprozomib (ONX 0912)': 91, 'Oxybenzone': 92, 'PD-0325901': 93, 'PF-03814735': 94, 'PF-04691502': 95, 'PRT-062607': 96, 'Palbociclib': 97, 'Penfluridol': 98, 'Perhexiline': 99, 'Phenylbutazone': 100, 'Pitavastatin Calcium': 101, 'Pomalidomide': 102, 'Porcn Inhibitor III': 103, 'Prednisolone': 104, 'Proscillaridin A;Proscillaridin-A': 105, 'Protriptyline': 106, 'Quizartinib': 107, 'R428': 108, 'RG7090': 109, 'RG7112': 110, 'RN-486': 111, 'RVX-208': 112, 'Raloxifene': 113, 'Resminostat': 114, 'Ricolinostat': 115, 'Riociguat': 116, 'Ruxolitinib': 117, 'SB525334': 118, 'SCH-58261': 119, 'SLx-2119': 120, 'STK219801': 121, 'Saracatinib': 122, 'Scriptaid': 123, 'Selumetinib': 124, 'Sgc-cbp30': 125, 'Sunitinib': 126, 'TGX 221': 127, 'TIE2 Kinase Inhibitor': 128, 'TL_HRAS26': 129, 'TPCA-1': 130, 'TR-14035': 131, 'Tacalcitol': 132, 'Tamatinib': 133, 'Tipifarnib': 134, 'Tivantinib': 135, 'Tivozanib': 136, 'Topotecan': 137, 'Tosedostat': 138, 'Trametinib': 139, 'UNII-BXU45ZH6LI': 140, 'Vandetanib': 141, 'Vanoxerine': 142, 'Vardenafil': 143, 'Vorinostat': 144, 'YK 4-279': 145}

# %% [markdown]
# ## Dataset Construct

# %%
def Obtain_VAE_data(parquet_file_path: str) -> np.ndarray:
    # Load the Parquet file into a DataFrame
    df = pd.read_parquet(parquet_file_path)

    # The name of the column to transform
    column_to_transform = "cell_type"

    # Replace the values in the column based on the dictionary
    df[column_to_transform] = df[column_to_transform].map(ct2idx)

    # The name of the column to transform
    column_to_transform = "sm_name"

    # Replace the values in the column based on the dictionary
    df[column_to_transform] = df[column_to_transform].map(pert2idx)

    df.drop(columns=["sm_lincs_id", "SMILES"], inplace=True)
    # ,'control'

    return df.values

# %%
# Replace with your actual file path
training_path = r"/content/drive/MyDrive/Project_MingyuZhong_Ver.11.10/Project/data/data_train.parquet"
training_data = Obtain_VAE_data(training_path)
print(training_data)
# Out:
# [[5 103 False ... 1.1474819425496732 -0.0013708856043735814
#   -0.5387391267629659]
#  [4 44 False ... 0.14008628240333457 -0.27597584820022547
#   0.30352137303390303]
#  [4 5 False ... 0.3415228027084855 -0.48192001204442475
#   0.007458666648073425]
#  ...
#  [4 82 False ... -0.060238740601505275 0.8770697568907733
#   1.0929688729439277]
#  [1 12 False ... -0.8517764052953564 0.04442567270763101
#   -0.497355486141355]
#  [2 92 False ... -0.1867229415185727 0.443236562810196 0.5938353783439132]]

# %%
class ParquetDataset(Dataset):
    def __init__(self, filename):
        self.data = Obtain_VAE_data(filename)
        # print(self.data.head(2))
        # print(self.data.shape)
        self.data = torch.tensor(self.data, dtype=torch.float32)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data_row = self.data[idx]
        tuple_pair = data_row[:2]  # First two columns
        Gene_DEVs = data_row[2:]  # Remaining columns
        return Gene_DEVs, tuple_pair

# %% [markdown]
# ## Metric Definition

# %%
def mean_rowwise_rmse(output, target):
    """
    Compute Mean Rowwise Root Mean Squared Error.

    Args:
        output (torch.Tensor): The model's output.
        target (torch.Tensor): The target values.

    Returns:
        torch.Tensor: The mean rowwise RMSE.
    """
    mse_per_row = torch.mean((output - target) ** 2, dim=1)
    rmse_per_row = torch.sqrt(mse_per_row)
    return torch.mean(rmse_per_row)

# %% [markdown]
# ## Model Definitions

# %%
class VAE(nn.Module):
    """
    Variational Autoencoder (VAE) for predicting 18,000 Gene DEV based on (cell type, Perturbagen) tuple pair.
    """

    class Encoder(nn.Module):
        """
        Encoder network for VAE.
        """

        def __init__(self, num_features: int, dropout_rate: float):
            super().__init__()
            # Adjusting layer dimensions as per the specified architecture
            self.fc1 = nn.Linear(num_features, 1024)
            self.bn1 = nn.BatchNorm1d(1024)
            self.attention1 = nn.MultiheadAttention(1024, num_heads=4, batch_first=True)

            self.fc2 = nn.Linear(1024, 128)
            self.bn2 = nn.BatchNorm1d(128)
            self.attention2 = nn.MultiheadAttention(128, num_heads=4, batch_first=True)

            self.fc3 = nn.Linear(128, 16)
            self.bn3 = nn.BatchNorm1d(16)
            self.attention3 = nn.MultiheadAttention(16, num_heads=4, batch_first=True)

            # Separate outputs for mean and standard deviation
            self.fc_mu = nn.Linear(16, 2)
            self.fc_log_var = nn.Linear(16, 2)
            self.dropout = nn.Dropout(dropout_rate)
            self.act_fn = nn.LeakyReLU()

        def forward(self, x: torch.Tensor) -> (torch.Tensor, torch.Tensor):
            x = self.act_fn(self.bn1(self.fc1(x)))
            x = self.dropout(x)

            # resid = x
            # x, _ = self.attention1(x, x, x)
            # x = x + resid
            # x = self.dropout(x)

            x = self.act_fn(self.bn2(self.fc2(x)))
            x = self.dropout(x)

            # resid = x
            # x, _ = self.attention2(x, x, x)
            # x = x + resid
            # x = self.dropout(x)

            x = self.act_fn(self.bn3(self.fc3(x)))
            x = self.dropout(x)

            # resid = x
            # x, _ = self.attention3(x, x, x)
            # x = x + resid
            # x = self.dropout(x)

            mu = self.fc_mu(x)
            log_var = self.fc_log_var(x)
            return mu, log_var

    class Decoder(nn.Module):
        """
        Decoder network for VAE.
        """

        def __init__(self, num_features: int, dropout_rate: float):
            super().__init__()
            # Reversing the architecture of the encoder
            self.fc1 = nn.Linear(2, 16)
            self.bn1 = nn.BatchNorm1d(16)
            self.fc2 = nn.Linear(16, 128)
            self.bn2 = nn.BatchNorm1d(128)
            self.fc3 = nn.Linear(128, 1024)
            self.bn3 = nn.BatchNorm1d(1024)
            self.fc4 = nn.Linear(
                1024, num_features
            )  # Output layer matching Gene DEV dimension
            self.dropout = nn.Dropout(dropout_rate)
            self.act_fn = nn.LeakyReLU()
            self.attention1 = nn.MultiheadAttention(16, num_heads=4, batch_first=True)
            self.attention2 = nn.MultiheadAttention(128, num_heads=4, batch_first=True)
            self.attention3 = nn.MultiheadAttention(1024, num_heads=4, batch_first=True)

        def forward(self, z: torch.Tensor) -> torch.Tensor:
            z = self.act_fn(self.bn1(self.fc1(z)))
            z = self.dropout(z)

            # resid = z
            # z, _ = self.attention1(z, z, z)
            # z = z + resid
            # z = self.dropout(z)

            z = self.act_fn(self.bn2(self.fc2(z)))
            z = self.dropout(z)

            # resid = z
            # z, _ = self.attention2(z, z, z)
            # z = z + resid
            # z = self.dropout(z)

            z = self.act_fn(self.bn3(self.fc3(z)))
            z = self.dropout(z)

            # resid = z
            # z, _ = self.attention3(z, z, z)
            # z = z + resid
            # z = self.dropout(z)

            reconstruction = self.fc4(z)
            return reconstruction

    def __init__(self, num_features: int, dropout_rate: float):
        super(VAE, self).__init__()
        self.encoder = self.Encoder(num_features, dropout_rate)
        self.decoder = self.Decoder(num_features, dropout_rate)

    def reparameterize(self, mu: torch.Tensor, log_var: torch.Tensor) -> torch.Tensor:
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def encode(self, x: torch.Tensor) -> torch.Tensor:
        mu, log_var = self.encoder(x)
        z = self.reparameterize(mu, log_var)
        return z

    def decode(self, z: torch.Tensor) -> torch.Tensor:
        x_reconstructed = self.decoder(z)
        return x_reconstructed

    def forward(self, x: torch.Tensor) -> (torch.Tensor, torch.Tensor, torch.Tensor):
        mu, log_var = self.encoder(x)
        z = self.reparameterize(mu, log_var)
        x_reconstructed = self.decoder(z)
        return x_reconstructed, mu, log_var

# %%
def vae_loss(
    x_decoded_mean: torch.Tensor,
    x: torch.Tensor,
    z_mean: torch.Tensor,
    z_logvar: torch.Tensor,
    mu_t: torch.Tensor,
    std_t: torch.Tensor,
    device: torch.device,
) -> torch.Tensor:
    """
    Calculate the loss for the Variational Autoencoder.

    Parameters:
        x_decoded_mean (torch.Tensor): The decoded output of the VAE.
        x (torch.Tensor): The original input data.
        z_mean (torch.Tensor): Mean of the latent space.
        z_logvar (torch.Tensor): Log variance of the latent space.
        mu_t (torch.Tensor): Prior mean of the latent space distribution.
        std_t (torch.Tensor): Prior standard deviation of the latent space distribution.
        device (torch.device): The device (CPU or GPU) where the tensors are located.

    Returns:
        torch.Tensor: The calculated VAE loss.
    """
    # Reconstruction Loss
    recon_loss = F.mse_loss(x_decoded_mean, x, reduction="mean")

    # KL Divergence Loss
    covar_q = torch.exp(z_logvar).to(device)  # Variance of the learned distribution
    covar_p = torch.ones_like(covar_q).to(device) * std_t.pow(
        2
    )  # Variance of the prior distribution

    mu_adjusted = z_mean - mu_t.to(device).unsqueeze(1)  # Adjusting the mean

    # KL Divergence calculation
    matrix_sum = (
        torch.log(covar_p) - z_logvar - 1 + (mu_adjusted.pow(2) + covar_q) / covar_p
    )
    kl_div = 0.5 * torch.sum(matrix_sum, dim=1)
    kl_loss = torch.mean(kl_div)

    return recon_loss + kl_loss

# %%
import torch
import torch.nn.functional as F


def train_np(
    model,
    train_loader,
    val_loader,
    n_epochs=100,
    lr=0.01,
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu"),
):
    # # Data loaders
    # train_loader = torch.utils.data.DataLoader(
    #     dataset=train_data, batch_size=batch_size, shuffle=True
    # )
    # val_loader = torch.utils.data.DataLoader(
    #     dataset=val_data, batch_size=batch_size, shuffle=False
    # )
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = ReduceLROnPlateau(
        optimizer, mode="min", factor=0.1, patience=128, verbose=True
    )

    best_val_loss = float("inf")
    # Training loop
    for epoch in range(1, n_epochs + 1):
        # Training mode
        model.train()

        train_loss, train_rmse = 0.0, 0.0

        for batch_idx, batch_x in enumerate(train_loader):
            data, mu_t = batch_x
            # batch_x[:, :-1], batch_x[:, -1]
            mu_t = torch.unsqueeze(mu_t, 1)
            mu_std = torch.tensor([1], dtype=torch.float32)
            data, mu_t, mu_std = data.to(device), mu_t.to(device), mu_std.to(device)

            # Forward pass
            output, mean, logvar = model(data)
            loss = vae_loss(output, data, mean, logvar, mu_t, mu_std, device)

            # Update
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_rmse += mean_rowwise_rmse(output, data).item()

        # Calculate average training loss for the epoch
        train_loss /= len(train_loader)
        train_rmse /= len(train_loader)

        # Validation mode
        model.eval()
        val_loss, val_rmse = 0.0, 0.0
        with torch.no_grad():
            for batch_x in val_loader:
                data, mu_t = batch_x
                # [:, :-1], batch_x[:, -1]
                mu_t = torch.unsqueeze(mu_t, 1)
                data, mu_t = data.to(device), mu_t.to(device)

                # Forward pass
                output, mean, logvar = model(data)
                loss = vae_loss(output, data, mean, logvar, mu_t, mu_std, device)

                val_loss += loss.item()
                val_rmse += mean_rowwise_rmse(output, data).item()

        # Calculate average validation loss for the epoch
        val_loss /= len(val_loader)
        val_rmse /= len(val_loader)
        print(
            f"Epoch {epoch} - Train Loss: {train_loss:.4f}, Train MRRMSE: {train_rmse:.4f}, Validation Loss: {val_loss:.4f}, Validation MRRMSE: {val_rmse:.4f}"
        )

        scheduler.step(val_loss)
        if val_loss < best_val_loss:
            best_val_loss = val_loss
    return model

# %%
Gene_DEVs, tuple_pair = next(train_data_iterator)

num_features = Gene_DEVs.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-76e6acae03f7> in <cell line: 1>()
# ----> 1 Gene_DEVs, tuple_pair = next(train_data_iterator)
#       2
#       3 num_features = Gene_DEVs.shape[1]
#
# NameError: name 'train_data_iterator' is not defined

# %% [markdown]
# ## Model & Dataset Initialization

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

train_path = r"/content/drive/MyDrive/Project_MingyuZhong_Ver.11.10/Project/data/data_train.parquet"
valid_path = r"/content/drive/MyDrive/Project_MingyuZhong_Ver.11.10/Project/data/data_val.parquet"

train_dataset = ParquetDataset(train_path)
train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True)
valid_dataset = ParquetDataset(valid_path)
valid_dataloader = DataLoader(valid_dataset, batch_size=256, shuffle=False)

# Create an iterator from the dataloader
train_data_iterator = iter(train_dataloader)

# Fetch the next batch
Gene_DEVs, tuple_pair = next(train_data_iterator)

num_features = Gene_DEVs.shape[1]
dropout_rate = 0.19

# Instantiate the VAE model
vae_model = VAE(num_features=num_features, dropout_rate=dropout_rate)

# Generate the model summary
model_summary = summary(vae_model, input_size=(1, num_features))

print(model_summary)
# Out:
# cuda
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-5376f1e146fd> in <cell line: 7>()
#       5 valid_path = r"/content/drive/MyDrive/Project_MingyuZhong_Ver.11.10/Project/data/data_val.parquet"
#       6
# ----> 7 train_dataset = ParquetDataset(train_path)
#       8 train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True)
#       9 valid_dataset = ParquetDataset(valid_path)
#
# <ipython-input-10-08c13a32e994> in __init__(self, filename)
#       4         # print(self.data.head(2))
#       5         # print(self.data.shape)
# ----> 6         self.data = torch.tensor(self.data, dtype=torch.float32)
#       7
#       8     def __len__(self):
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint8, and bool.

# %% [markdown]
# ## Training

# %%
vae = train_np(
    vae_model, train_loader=train_dataloader, val_loader=valid_dataloader, n_epochs=1000
)
# Out:
# Epoch 1 - Train Loss: 1730.7991, Train MRRMSE: 2.0135, Validation Loss: 2057.8450, Validation MRRMSE: 1.2323
# Epoch 2 - Train Loss: 1698.1965, Train MRRMSE: 1.8813, Validation Loss: 1986.6821, Validation MRRMSE: 1.1171
# Epoch 3 - Train Loss: 1719.8886, Train MRRMSE: 1.7535, Validation Loss: 1973.4066, Validation MRRMSE: 1.2047
# Epoch 4 - Train Loss: 1684.1452, Train MRRMSE: 1.4933, Validation Loss: 1958.7358, Validation MRRMSE: 1.1042
# Epoch 5 - Train Loss: 1664.0436, Train MRRMSE: 1.4092, Validation Loss: 1944.3069, Validation MRRMSE: 1.2056
# Epoch 6 - Train Loss: 1637.8923, Train MRRMSE: 1.3229, Validation Loss: 1928.3425, Validation MRRMSE: 1.0562
# Epoch 7 - Train Loss: 1642.6296, Train MRRMSE: 1.3229, Validation Loss: 1921.2729, Validation MRRMSE: 1.7954
# Epoch 8 - Train Loss: 1590.9657, Train MRRMSE: 1.2047, Validation Loss: 1891.0306, Validation MRRMSE: 1.0933
# Epoch 9 - Train Loss: 1613.3488, Train MRRMSE: 1.2868, Validation Loss: 1867.2418, Validation MRRMSE: 1.0014
# Epoch 10 - Train Loss: 1580.7293, Train MRRMSE: 1.2919, Validation Loss: 1843.5060, Validation MRRMSE: 1.0367
# Epoch 11 - Train Loss: 1566.9640, Train MRRMSE: 1.1755, Validation Loss: 1815.0397, Validation MRRMSE: 1.4522
# Epoch 12 - Train Loss: 1520.0213, Train MRRMSE: 1.2376, Validation Loss: 1775.9050, Validation MRRMSE: 0.9953
# Epoch 13 - Train Loss: 1477.0494, Train MRRMSE: 1.3431, Validation Loss: 1738.4618, Validation MRRMSE: 1.0519
# Epoch 14 - Train Loss: 1445.6098, Train MRRMSE: 1.2976, Validation Loss: 1702.2174, Validation MRRMSE: 1.0296
# Epoch 15 - Train Loss: 1420.0439, Train MRRMSE: 1.3265, Validation Loss: 1673.4725, Validation MRRMSE: 1.0242
# Epoch 16 - Train Loss: 1376.0172, Train MRRMSE: 1.3702, Validation Loss: 1636.8625, Validation MRRMSE: 1.0598
# Epoch 17 - Train Loss: 1329.2491, Train MRRMSE: 1.2979, Validation Loss: 1591.7650, Validation MRRMSE: 1.0758
# Epoch 18 - Train Loss: 1298.0359, Train MRRMSE: 1.3503, Validation Loss: 1538.9100, Validation MRRMSE: 1.2169
# Epoch 19 - Train Loss: 1255.1882, Train MRRMSE: 1.3594, Validation Loss: 1486.3325, Validation MRRMSE: 1.8172
# Epoch 20 - Train Loss: 1207.4607, Train MRRMSE: 1.3981, Validation Loss: 1437.0818, Validation MRRMSE: 1.5499
# Epoch 21 - Train Loss: 1165.0702, Train MRRMSE: 1.4123, Validation Loss: 1384.5933, Validation MRRMSE: 1.7395
# Epoch 22 - Train Loss: 1130.7218, Train MRRMSE: 1.4120, Validation Loss: 1313.3824, Validation MRRMSE: 1.2980
# Epoch 23 - Train Loss: 1059.8786, Train MRRMSE: 1.3959, Validation Loss: 1253.9812, Validation MRRMSE: 1.7815
# Epoch 24 - Train Loss: 1020.7232, Train MRRMSE: 1.3822, Validation Loss: 1205.4812, Validation MRRMSE: 1.2431
# Epoch 25 - Train Loss: 974.5672, Train MRRMSE: 1.3299, Validation Loss: 1152.5375, Validation MRRMSE: 1.1223
# Epoch 26 - Train Loss: 908.2650, Train MRRMSE: 1.3559, Validation Loss: 1073.0546, Validation MRRMSE: 1.0707
# Epoch 27 - Train Loss: 880.3244, Train MRRMSE: 1.3393, Validation Loss: 1018.7385, Validation MRRMSE: 1.1211
# Epoch 28 - Train Loss: 842.4459, Train MRRMSE: 1.3244, Validation Loss: 989.7749, Validation MRRMSE: 1.2975
# Epoch 29 - Train Loss: 792.1458, Train MRRMSE: 1.4224, Validation Loss: 944.4082, Validation MRRMSE: 1.1019
# Epoch 30 - Train Loss: 724.9735, Train MRRMSE: 1.3358, Validation Loss: 913.4077, Validation MRRMSE: 1.1106
# Epoch 31 - Train Loss: 701.6700, Train MRRMSE: 1.3464, Validation Loss: 874.2807, Validation MRRMSE: 1.1310
# Epoch 32 - Train Loss: 668.6086, Train MRRMSE: 1.3735, Validation Loss: 803.1154, Validation MRRMSE: 1.1012
# Epoch 33 - Train Loss: 645.8457, Train MRRMSE: 1.4226, Validation Loss: 777.0820, Validation MRRMSE: 1.1766
# Epoch 34 - Train Loss: 609.0987, Train MRRMSE: 1.4161, Validation Loss: 734.6096, Validation MRRMSE: 1.0705
# Epoch 35 - Train Loss: 587.9346, Train MRRMSE: 1.3301, Validation Loss: 704.4527, Validation MRRMSE: 1.1152
# Epoch 36 - Train Loss: 560.5766, Train MRRMSE: 1.3460, Validation Loss: 676.3817, Validation MRRMSE: 1.1201
# Epoch 37 - Train Loss: 535.6979, Train MRRMSE: 1.3358, Validation Loss: 640.3467, Validation MRRMSE: 1.1586
# Epoch 38 - Train Loss: 524.5534, Train MRRMSE: 1.3515, Validation Loss: 626.6726, Validation MRRMSE: 1.1582
# Epoch 39 - Train Loss: 507.6988, Train MRRMSE: 1.3606, Validation Loss: 608.7045, Validation MRRMSE: 1.1841
# Epoch 40 - Train Loss: 492.5768, Train MRRMSE: 1.3200, Validation Loss: 579.3145, Validation MRRMSE: 1.1022
# Epoch 41 - Train Loss: 493.9361, Train MRRMSE: 1.3287, Validation Loss: 562.8904, Validation MRRMSE: 1.1120
# Epoch 42 - Train Loss: 489.6060, Train MRRMSE: 1.3157, Validation Loss: 546.1289, Validation MRRMSE: 1.0726
# Epoch 43 - Train Loss: 483.0022, Train MRRMSE: 1.2633, Validation Loss: 533.4017, Validation MRRMSE: 1.1123
# Epoch 44 - Train Loss: 480.9526, Train MRRMSE: 1.2981, Validation Loss: 523.8507, Validation MRRMSE: 1.1326
# Epoch 45 - Train Loss: 479.7017, Train MRRMSE: 1.2796, Validation Loss: 519.1212, Validation MRRMSE: 1.1940
# Epoch 46 - Train Loss: 480.6674, Train MRRMSE: 1.3011, Validation Loss: 514.2126, Validation MRRMSE: 1.2079
# Epoch 47 - Train Loss: 475.3747, Train MRRMSE: 1.2618, Validation Loss: 504.0970, Validation MRRMSE: 1.2605
# Epoch 48 - Train Loss: 475.5941, Train MRRMSE: 1.2919, Validation Loss: 511.1019, Validation MRRMSE: 1.0011
# Epoch 49 - Train Loss: 473.3172, Train MRRMSE: 1.2402, Validation Loss: 509.9030, Validation MRRMSE: 1.0765
# Epoch 50 - Train Loss: 472.0295, Train MRRMSE: 1.2554, Validation Loss: 499.7979, Validation MRRMSE: 1.0490
# Epoch 51 - Train Loss: 469.1781, Train MRRMSE: 1.2577, Validation Loss: 488.7987, Validation MRRMSE: 1.0063
# Epoch 52 - Train Loss: 470.5505, Train MRRMSE: 1.2256, Validation Loss: 497.2443, Validation MRRMSE: 1.0431
# Epoch 53 - Train Loss: 478.6103, Train MRRMSE: 1.2228, Validation Loss: 491.2113, Validation MRRMSE: 1.1241
# Epoch 54 - Train Loss: 471.6415, Train MRRMSE: 1.2364, Validation Loss: 494.7330, Validation MRRMSE: 1.6497
# Epoch 55 - Train Loss: 474.0201, Train MRRMSE: 1.2434, Validation Loss: 500.6588, Validation MRRMSE: 1.4435
# Epoch 56 - Train Loss: 472.8862, Train MRRMSE: 1.1788, Validation Loss: 496.0964, Validation MRRMSE: 1.3938
# Epoch 57 - Train Loss: 472.6438, Train MRRMSE: 1.2256, Validation Loss: 495.7529, Validation MRRMSE: 1.0946
# Epoch 58 - Train Loss: 469.8108, Train MRRMSE: 1.2690, Validation Loss: 494.0940, Validation MRRMSE: 1.0835
# Epoch 59 - Train Loss: 474.8428, Train MRRMSE: 1.2388, Validation Loss: 500.1893, Validation MRRMSE: 1.0454
# Epoch 60 - Train Loss: 473.8216, Train MRRMSE: 1.2675, Validation Loss: 504.2198, Validation MRRMSE: 1.0448
# Epoch 61 - Train Loss: 470.3360, Train MRRMSE: 1.2124, Validation Loss: 509.1658, Validation MRRMSE: 1.0483
# Epoch 62 - Train Loss: 473.7536, Train MRRMSE: 1.2414, Validation Loss: 512.8359, Validation MRRMSE: 1.0486
# Epoch 63 - Train Loss: 472.0066, Train MRRMSE: 1.1755, Validation Loss: 507.7493, Validation MRRMSE: 1.0148
# Epoch 64 - Train Loss: 467.2524, Train MRRMSE: 1.2127, Validation Loss: 495.3040, Validation MRRMSE: 1.1051
# Epoch 65 - Train Loss: 469.4053, Train MRRMSE: 1.2476, Validation Loss: 480.8666, Validation MRRMSE: 1.0597
# Epoch 66 - Train Loss: 467.6589, Train MRRMSE: 1.1945, Validation Loss: 475.0179, Validation MRRMSE: 1.0010
# Epoch 67 - Train Loss: 473.2474, Train MRRMSE: 1.1974, Validation Loss: 474.0906, Validation MRRMSE: 0.9926
# Epoch 68 - Train Loss: 469.9970, Train MRRMSE: 1.1713, Validation Loss: 483.3223, Validation MRRMSE: 0.9894
# Epoch 69 - Train Loss: 477.6616, Train MRRMSE: 1.2348, Validation Loss: 486.1121, Validation MRRMSE: 0.9766
# Epoch 70 - Train Loss: 462.1122, Train MRRMSE: 1.1971, Validation Loss: 484.6489, Validation MRRMSE: 1.0521
# Epoch 71 - Train Loss: 478.4913, Train MRRMSE: 1.2415, Validation Loss: 480.3737, Validation MRRMSE: 1.0411
# Epoch 72 - Train Loss: 467.1971, Train MRRMSE: 1.2330, Validation Loss: 482.9487, Validation MRRMSE: 1.0667
# Epoch 73 - Train Loss: 469.7036, Train MRRMSE: 1.1917, Validation Loss: 482.7315, Validation MRRMSE: 1.0800
# Epoch 74 - Train Loss: 471.9851, Train MRRMSE: 1.1821, Validation Loss: 480.2493, Validation MRRMSE: 1.0051
# Epoch 75 - Train Loss: 468.1837, Train MRRMSE: 1.2383, Validation Loss: 479.4306, Validation MRRMSE: 1.0075
# Epoch 76 - Train Loss: 464.8133, Train MRRMSE: 1.1932, Validation Loss: 481.5198, Validation MRRMSE: 1.0374
# Epoch 77 - Train Loss: 464.2405, Train MRRMSE: 1.2097, Validation Loss: 481.0066, Validation MRRMSE: 1.0665
# Epoch 78 - Train Loss: 469.8825, Train MRRMSE: 1.2348, Validation Loss: 477.5739, Validation MRRMSE: 1.4463
# Epoch 79 - Train Loss: 476.9084, Train MRRMSE: 1.1561, Validation Loss: 474.6094, Validation MRRMSE: 1.5245
# Epoch 80 - Train Loss: 466.7843, Train MRRMSE: 1.2099, Validation Loss: 473.9151, Validation MRRMSE: 1.3202
# Epoch 81 - Train Loss: 470.0757, Train MRRMSE: 1.2171, Validation Loss: 476.0467, Validation MRRMSE: 1.1204
# Epoch 82 - Train Loss: 460.5827, Train MRRMSE: 1.2094, Validation Loss: 481.0971, Validation MRRMSE: 1.1396
# Epoch 83 - Train Loss: 470.7047, Train MRRMSE: 1.2098, Validation Loss: 484.8600, Validation MRRMSE: 1.1019
# Epoch 84 - Train Loss: 474.2353, Train MRRMSE: 1.1911, Validation Loss: 485.3833, Validation MRRMSE: 1.4436
# Epoch 85 - Train Loss: 468.2023, Train MRRMSE: 1.2113, Validation Loss: 479.2453, Validation MRRMSE: 1.2380
# Epoch 86 - Train Loss: 463.0506, Train MRRMSE: 1.2279, Validation Loss: 479.4779, Validation MRRMSE: 1.0976
# Epoch 87 - Train Loss: 475.2591, Train MRRMSE: 1.2666, Validation Loss: 484.6947, Validation MRRMSE: 1.0854
# Epoch 88 - Train Loss: 472.6819, Train MRRMSE: 1.2113, Validation Loss: 479.8206, Validation MRRMSE: 1.0593
# Epoch 89 - Train Loss: 464.1871, Train MRRMSE: 1.1930, Validation Loss: 474.0844, Validation MRRMSE: 1.0327
# Epoch 90 - Train Loss: 464.0483, Train MRRMSE: 1.2062, Validation Loss: 472.8345, Validation MRRMSE: 1.0161
# Epoch 91 - Train Loss: 466.8961, Train MRRMSE: 1.2403, Validation Loss: 473.9955, Validation MRRMSE: 1.0051
# Epoch 92 - Train Loss: 475.2942, Train MRRMSE: 1.2195, Validation Loss: 471.6721, Validation MRRMSE: 1.0698
# Epoch 93 - Train Loss: 475.6403, Train MRRMSE: 1.2175, Validation Loss: 473.5143, Validation MRRMSE: 1.0447
# Epoch 94 - Train Loss: 467.6564, Train MRRMSE: 1.1786, Validation Loss: 469.9857, Validation MRRMSE: 1.0362
# Epoch 95 - Train Loss: 465.6619, Train MRRMSE: 1.1680, Validation Loss: 468.5060, Validation MRRMSE: 1.0268
# Epoch 96 - Train Loss: 476.3286, Train MRRMSE: 1.2116, Validation Loss: 473.6346, Validation MRRMSE: 1.0438
# Epoch 97 - Train Loss: 471.0466, Train MRRMSE: 1.2288, Validation Loss: 476.5828, Validation MRRMSE: 1.1148
# Epoch 98 - Train Loss: 471.0725, Train MRRMSE: 1.2082, Validation Loss: 479.6632, Validation MRRMSE: 1.0795
# Epoch 99 - Train Loss: 463.4812, Train MRRMSE: 1.2133, Validation Loss: 479.7601, Validation MRRMSE: 1.0724
# Epoch 100 - Train Loss: 466.7155, Train MRRMSE: 1.2009, Validation Loss: 474.4387, Validation MRRMSE: 1.0293
# Epoch 101 - Train Loss: 466.8172, Train MRRMSE: 1.1779, Validation Loss: 474.9410, Validation MRRMSE: 1.0506
# Epoch 102 - Train Loss: 466.2078, Train MRRMSE: 1.1824, Validation Loss: 475.6444, Validation MRRMSE: 1.0222
# Epoch 103 - Train Loss: 465.5167, Train MRRMSE: 1.1931, Validation Loss: 473.7153, Validation MRRMSE: 0.9889
# Epoch 104 - Train Loss: 467.9016, Train MRRMSE: 1.1478, Validation Loss: 472.6259, Validation MRRMSE: 0.9447
# Epoch 105 - Train Loss: 464.1881, Train MRRMSE: 1.1738, Validation Loss: 476.2227, Validation MRRMSE: 1.3317
# Epoch 106 - Train Loss: 468.4457, Train MRRMSE: 1.1858, Validation Loss: 475.0844, Validation MRRMSE: 1.5904
# Epoch 107 - Train Loss: 468.0575, Train MRRMSE: 1.1880, Validation Loss: 472.5828, Validation MRRMSE: 1.1878
# Epoch 108 - Train Loss: 472.2911, Train MRRMSE: 1.1988, Validation Loss: 473.2701, Validation MRRMSE: 1.0294
# Epoch 109 - Train Loss: 461.0927, Train MRRMSE: 1.2041, Validation Loss: 474.6060, Validation MRRMSE: 1.0610
# Epoch 110 - Train Loss: 467.3645, Train MRRMSE: 1.2105, Validation Loss: 474.3031, Validation MRRMSE: 1.0333
# Epoch 111 - Train Loss: 461.5812, Train MRRMSE: 1.2025, Validation Loss: 473.2557, Validation MRRMSE: 0.9886
# Epoch 112 - Train Loss: 472.9204, Train MRRMSE: 1.2010, Validation Loss: 470.6344, Validation MRRMSE: 1.0110
# Epoch 113 - Train Loss: 470.3654, Train MRRMSE: 1.1981, Validation Loss: 474.7224, Validation MRRMSE: 1.0128
# Epoch 114 - Train Loss: 470.2638, Train MRRMSE: 1.2120, Validation Loss: 481.7112, Validation MRRMSE: 0.9795
# Epoch 115 - Train Loss: 458.1779, Train MRRMSE: 1.2032, Validation Loss: 472.0152, Validation MRRMSE: 0.9648
# Epoch 116 - Train Loss: 465.6114, Train MRRMSE: 1.2423, Validation Loss: 470.6547, Validation MRRMSE: 0.9450
# Epoch 117 - Train Loss: 472.9189, Train MRRMSE: 1.1827, Validation Loss: 472.5991, Validation MRRMSE: 1.0208
# Epoch 118 - Train Loss: 470.8262, Train MRRMSE: 1.2264, Validation Loss: 474.9338, Validation MRRMSE: 1.0452
# Epoch 119 - Train Loss: 464.8809, Train MRRMSE: 1.2163, Validation Loss: 473.2430, Validation MRRMSE: 0.9716
# Epoch 120 - Train Loss: 470.0040, Train MRRMSE: 1.2339, Validation Loss: 473.5319, Validation MRRMSE: 1.0645
# Epoch 121 - Train Loss: 461.1600, Train MRRMSE: 1.2332, Validation Loss: 470.4629, Validation MRRMSE: 1.0220
# Epoch 122 - Train Loss: 465.3683, Train MRRMSE: 1.1794, Validation Loss: 469.2758, Validation MRRMSE: 0.9688
# Epoch 123 - Train Loss: 463.2296, Train MRRMSE: 1.1921, Validation Loss: 466.7170, Validation MRRMSE: 0.9970
# Epoch 124 - Train Loss: 467.5068, Train MRRMSE: 1.2207, Validation Loss: 469.0165, Validation MRRMSE: 1.0004
# Epoch 125 - Train Loss: 459.4694, Train MRRMSE: 1.1741, Validation Loss: 471.2207, Validation MRRMSE: 0.9865
# Epoch 126 - Train Loss: 469.4349, Train MRRMSE: 1.1707, Validation Loss: 475.0440, Validation MRRMSE: 1.0210
# Epoch 127 - Train Loss: 462.8794, Train MRRMSE: 1.1645, Validation Loss: 474.9426, Validation MRRMSE: 1.0560
# Epoch 128 - Train Loss: 467.8274, Train MRRMSE: 1.2001, Validation Loss: 473.9069, Validation MRRMSE: 1.0429
# Epoch 129 - Train Loss: 458.1456, Train MRRMSE: 1.1567, Validation Loss: 476.2890, Validation MRRMSE: 1.0260
# Epoch 130 - Train Loss: 464.0426, Train MRRMSE: 1.1866, Validation Loss: 476.0376, Validation MRRMSE: 0.9645
# Epoch 131 - Train Loss: 468.4330, Train MRRMSE: 1.2166, Validation Loss: 472.1868, Validation MRRMSE: 1.0389
# Epoch 132 - Train Loss: 463.2292, Train MRRMSE: 1.1757, Validation Loss: 469.4432, Validation MRRMSE: 0.9685
# Epoch 133 - Train Loss: 463.8170, Train MRRMSE: 1.1648, Validation Loss: 468.7625, Validation MRRMSE: 0.9779
# Epoch 134 - Train Loss: 467.3161, Train MRRMSE: 1.2344, Validation Loss: 471.0979, Validation MRRMSE: 1.0232
# Epoch 135 - Train Loss: 458.4672, Train MRRMSE: 1.1869, Validation Loss: 477.8109, Validation MRRMSE: 1.0477
# Epoch 136 - Train Loss: 460.9618, Train MRRMSE: 1.1513, Validation Loss: 479.0065, Validation MRRMSE: 0.9722
# Epoch 137 - Train Loss: 456.8427, Train MRRMSE: 1.1725, Validation Loss: 478.4162, Validation MRRMSE: 0.9801
# Epoch 138 - Train Loss: 464.3757, Train MRRMSE: 1.1591, Validation Loss: 476.8730, Validation MRRMSE: 0.9804
# Epoch 139 - Train Loss: 469.3429, Train MRRMSE: 1.2329, Validation Loss: 472.9821, Validation MRRMSE: 1.0229
# Epoch 140 - Train Loss: 459.1499, Train MRRMSE: 1.1862, Validation Loss: 470.9818, Validation MRRMSE: 0.9869
# Epoch 141 - Train Loss: 467.3461, Train MRRMSE: 1.1561, Validation Loss: 469.5152, Validation MRRMSE: 0.9550
# Epoch 142 - Train Loss: 461.5313, Train MRRMSE: 1.1437, Validation Loss: 469.0016, Validation MRRMSE: 0.9919
# Epoch 143 - Train Loss: 460.8563, Train MRRMSE: 1.1855, Validation Loss: 471.1969, Validation MRRMSE: 0.9999
# Epoch 144 - Train Loss: 465.0731, Train MRRMSE: 1.1919, Validation Loss: 473.6479, Validation MRRMSE: 1.0597
# Epoch 145 - Train Loss: 464.2773, Train MRRMSE: 1.1611, Validation Loss: 472.7747, Validation MRRMSE: 0.9697
# Epoch 146 - Train Loss: 461.9991, Train MRRMSE: 1.1758, Validation Loss: 471.4345, Validation MRRMSE: 1.0446
# Epoch 147 - Train Loss: 460.6566, Train MRRMSE: 1.1964, Validation Loss: 471.9993, Validation MRRMSE: 1.1026
# Epoch 148 - Train Loss: 464.5670, Train MRRMSE: 1.2270, Validation Loss: 470.5219, Validation MRRMSE: 0.9926
# Epoch 149 - Train Loss: 463.1749, Train MRRMSE: 1.2017, Validation Loss: 470.1643, Validation MRRMSE: 0.9600
# Epoch 150 - Train Loss: 466.0140, Train MRRMSE: 1.1786, Validation Loss: 467.8236, Validation MRRMSE: 1.0039
# Epoch 151 - Train Loss: 467.2970, Train MRRMSE: 1.1525, Validation Loss: 469.6658, Validation MRRMSE: 0.9555
# Epoch 152 - Train Loss: 462.0794, Train MRRMSE: 1.2100, Validation Loss: 472.2889, Validation MRRMSE: 0.9913
# Epoch 153 - Train Loss: 467.9340, Train MRRMSE: 1.1714, Validation Loss: 473.6160, Validation MRRMSE: 1.0216
# Epoch 154 - Train Loss: 471.3704, Train MRRMSE: 1.2300, Validation Loss: 474.4443, Validation MRRMSE: 1.0867
# Epoch 155 - Train Loss: 466.4741, Train MRRMSE: 1.2306, Validation Loss: 476.0573, Validation MRRMSE: 1.0794
# Epoch 156 - Train Loss: 461.0669, Train MRRMSE: 1.1614, Validation Loss: 474.1470, Validation MRRMSE: 0.9539
# Epoch 157 - Train Loss: 460.3705, Train MRRMSE: 1.1875, Validation Loss: 474.8233, Validation MRRMSE: 1.1060
# Epoch 158 - Train Loss: 468.3709, Train MRRMSE: 1.2208, Validation Loss: 469.3987, Validation MRRMSE: 1.1631
# Epoch 159 - Train Loss: 455.9016, Train MRRMSE: 1.1526, Validation Loss: 470.4625, Validation MRRMSE: 1.0099
# Epoch 160 - Train Loss: 466.6377, Train MRRMSE: 1.1689, Validation Loss: 470.8726, Validation MRRMSE: 1.0361
# Epoch 161 - Train Loss: 466.5889, Train MRRMSE: 1.2224, Validation Loss: 471.3535, Validation MRRMSE: 1.0601
# Epoch 162 - Train Loss: 456.8434, Train MRRMSE: 1.1886, Validation Loss: 471.0830, Validation MRRMSE: 0.9892
# Epoch 163 - Train Loss: 468.3478, Train MRRMSE: 1.1743, Validation Loss: 471.4431, Validation MRRMSE: 0.9909
# Epoch 164 - Train Loss: 464.2688, Train MRRMSE: 1.1765, Validation Loss: 470.3462, Validation MRRMSE: 0.9572
# Epoch 165 - Train Loss: 459.7831, Train MRRMSE: 1.1814, Validation Loss: 469.6229, Validation MRRMSE: 0.9472
# Epoch 166 - Train Loss: 461.9146, Train MRRMSE: 1.1919, Validation Loss: 471.4446, Validation MRRMSE: 1.0222
# Epoch 167 - Train Loss: 462.2558, Train MRRMSE: 1.1825, Validation Loss: 474.0973, Validation MRRMSE: 0.9733
# Epoch 168 - Train Loss: 461.6848, Train MRRMSE: 1.2124, Validation Loss: 474.2592, Validation MRRMSE: 0.9663
# Epoch 169 - Train Loss: 463.7877, Train MRRMSE: 1.2161, Validation Loss: 475.8148, Validation MRRMSE: 0.9890
# Epoch 170 - Train Loss: 466.0323, Train MRRMSE: 1.1862, Validation Loss: 470.4940, Validation MRRMSE: 0.9841
# Epoch 171 - Train Loss: 464.0562, Train MRRMSE: 1.1829, Validation Loss: 466.6714, Validation MRRMSE: 0.9675
# Epoch 172 - Train Loss: 463.5176, Train MRRMSE: 1.1633, Validation Loss: 467.2965, Validation MRRMSE: 1.0098
# Epoch 173 - Train Loss: 465.5735, Train MRRMSE: 1.1773, Validation Loss: 470.2293, Validation MRRMSE: 1.0077
# Epoch 174 - Train Loss: 468.5584, Train MRRMSE: 1.2724, Validation Loss: 474.8444, Validation MRRMSE: 1.0296
# Epoch 175 - Train Loss: 462.4903, Train MRRMSE: 1.1794, Validation Loss: 474.7013, Validation MRRMSE: 0.9884
# Epoch 176 - Train Loss: 464.5237, Train MRRMSE: 1.2363, Validation Loss: 473.3196, Validation MRRMSE: 0.9966
# Epoch 177 - Train Loss: 462.2843, Train MRRMSE: 1.1460, Validation Loss: 474.7905, Validation MRRMSE: 0.9937
# Epoch 178 - Train Loss: 459.2389, Train MRRMSE: 1.1631, Validation Loss: 473.9291, Validation MRRMSE: 1.0071
# Epoch 179 - Train Loss: 463.3303, Train MRRMSE: 1.1720, Validation Loss: 471.5403, Validation MRRMSE: 0.9731
# Epoch 180 - Train Loss: 459.9965, Train MRRMSE: 1.1502, Validation Loss: 468.7424, Validation MRRMSE: 0.9502
# Epoch 181 - Train Loss: 468.0197, Train MRRMSE: 1.2487, Validation Loss: 469.6953, Validation MRRMSE: 0.9773
# Epoch 182 - Train Loss: 462.8467, Train MRRMSE: 1.1723, Validation Loss: 470.4021, Validation MRRMSE: 1.0266
# Epoch 183 - Train Loss: 469.2189, Train MRRMSE: 1.1770, Validation Loss: 469.7018, Validation MRRMSE: 0.9700
# Epoch 184 - Train Loss: 460.2304, Train MRRMSE: 1.1747, Validation Loss: 467.7601, Validation MRRMSE: 0.9461
# Epoch 185 - Train Loss: 462.1544, Train MRRMSE: 1.1803, Validation Loss: 469.2620, Validation MRRMSE: 1.0041
# Epoch 186 - Train Loss: 463.8591, Train MRRMSE: 1.1704, Validation Loss: 473.1628, Validation MRRMSE: 1.0301
# Epoch 187 - Train Loss: 470.5620, Train MRRMSE: 1.2060, Validation Loss: 471.7275, Validation MRRMSE: 1.0064
# Epoch 188 - Train Loss: 458.9977, Train MRRMSE: 1.2283, Validation Loss: 471.8989, Validation MRRMSE: 1.0526
# Epoch 189 - Train Loss: 463.1973, Train MRRMSE: 1.1770, Validation Loss: 466.9356, Validation MRRMSE: 0.9939
# Epoch 190 - Train Loss: 458.6642, Train MRRMSE: 1.2258, Validation Loss: 466.2269, Validation MRRMSE: 0.9964
# Epoch 191 - Train Loss: 464.1158, Train MRRMSE: 1.1388, Validation Loss: 469.2096, Validation MRRMSE: 0.9474
# Epoch 192 - Train Loss: 464.1965, Train MRRMSE: 1.1789, Validation Loss: 473.5481, Validation MRRMSE: 0.9410
# Epoch 193 - Train Loss: 467.7160, Train MRRMSE: 1.1652, Validation Loss: 475.2530, Validation MRRMSE: 0.9814
# Epoch 194 - Train Loss: 461.0195, Train MRRMSE: 1.1415, Validation Loss: 473.8233, Validation MRRMSE: 1.0666
# Epoch 195 - Train Loss: 462.1289, Train MRRMSE: 1.2201, Validation Loss: 473.5547, Validation MRRMSE: 1.0136
# Epoch 196 - Train Loss: 462.6683, Train MRRMSE: 1.2067, Validation Loss: 471.8389, Validation MRRMSE: 0.9857
# Epoch 197 - Train Loss: 465.6759, Train MRRMSE: 1.2264, Validation Loss: 470.4544, Validation MRRMSE: 0.9619
# Epoch 198 - Train Loss: 469.3134, Train MRRMSE: 1.1964, Validation Loss: 470.4871, Validation MRRMSE: 1.0479
# Epoch 199 - Train Loss: 457.3021, Train MRRMSE: 1.1871, Validation Loss: 468.6045, Validation MRRMSE: 0.9991
# Epoch 200 - Train Loss: 462.7063, Train MRRMSE: 1.1765, Validation Loss: 469.0268, Validation MRRMSE: 1.0129
# Epoch 201 - Train Loss: 461.6377, Train MRRMSE: 1.1891, Validation Loss: 469.9590, Validation MRRMSE: 0.9485
# Epoch 202 - Train Loss: 462.9728, Train MRRMSE: 1.1538, Validation Loss: 471.6371, Validation MRRMSE: 1.0056
# Epoch 203 - Train Loss: 464.1926, Train MRRMSE: 1.1779, Validation Loss: 472.1363, Validation MRRMSE: 1.0272
# Epoch 204 - Train Loss: 459.1125, Train MRRMSE: 1.1889, Validation Loss: 470.2216, Validation MRRMSE: 1.0294
# Epoch 205 - Train Loss: 465.1805, Train MRRMSE: 1.1825, Validation Loss: 470.2349, Validation MRRMSE: 1.0179
# Epoch 206 - Train Loss: 462.0737, Train MRRMSE: 1.1868, Validation Loss: 471.6934, Validation MRRMSE: 1.0371
# Epoch 207 - Train Loss: 453.4504, Train MRRMSE: 1.1506, Validation Loss: 472.6716, Validation MRRMSE: 0.9885
# Epoch 208 - Train Loss: 465.4942, Train MRRMSE: 1.1703, Validation Loss: 470.2310, Validation MRRMSE: 0.9593
# Epoch 209 - Train Loss: 461.6684, Train MRRMSE: 1.1780, Validation Loss: 470.7224, Validation MRRMSE: 0.9767
# Epoch 210 - Train Loss: 463.2491, Train MRRMSE: 1.1706, Validation Loss: 470.1995, Validation MRRMSE: 0.9427
# Epoch 211 - Train Loss: 458.7358, Train MRRMSE: 1.1676, Validation Loss: 467.4360, Validation MRRMSE: 0.9643
# Epoch 212 - Train Loss: 461.7662, Train MRRMSE: 1.1637, Validation Loss: 467.2600, Validation MRRMSE: 0.9603
# Epoch 213 - Train Loss: 457.7680, Train MRRMSE: 1.2035, Validation Loss: 469.5501, Validation MRRMSE: 0.9571
# Epoch 214 - Train Loss: 462.6716, Train MRRMSE: 1.1666, Validation Loss: 471.3111, Validation MRRMSE: 0.9305
# Epoch 215 - Train Loss: 455.2968, Train MRRMSE: 1.1686, Validation Loss: 473.0224, Validation MRRMSE: 0.9327
# Epoch 216 - Train Loss: 460.4492, Train MRRMSE: 1.1802, Validation Loss: 473.1616, Validation MRRMSE: 0.9594
# Epoch 217 - Train Loss: 466.2703, Train MRRMSE: 1.2154, Validation Loss: 473.1980, Validation MRRMSE: 1.0316
# Epoch 218 - Train Loss: 464.4006, Train MRRMSE: 1.1667, Validation Loss: 473.5897, Validation MRRMSE: 1.0085
# Epoch 219 - Train Loss: 462.4041, Train MRRMSE: 1.1728, Validation Loss: 471.7656, Validation MRRMSE: 1.0037
# Epoch 220 - Train Loss: 455.3719, Train MRRMSE: 1.2076, Validation Loss: 472.0317, Validation MRRMSE: 1.0308
# Epoch 221 - Train Loss: 460.0184, Train MRRMSE: 1.2106, Validation Loss: 472.5199, Validation MRRMSE: 1.0168
# Epoch 222 - Train Loss: 468.1001, Train MRRMSE: 1.1794, Validation Loss: 472.6075, Validation MRRMSE: 1.0279
# Epoch 223 - Train Loss: 460.8418, Train MRRMSE: 1.1596, Validation Loss: 471.3365, Validation MRRMSE: 1.0430
# Epoch 224 - Train Loss: 457.5003, Train MRRMSE: 1.1603, Validation Loss: 473.6565, Validation MRRMSE: 1.0595
# Epoch 225 - Train Loss: 458.8687, Train MRRMSE: 1.1683, Validation Loss: 472.5508, Validation MRRMSE: 1.2675
# Epoch 226 - Train Loss: 463.6607, Train MRRMSE: 1.1466, Validation Loss: 472.2502, Validation MRRMSE: 1.0960
# Epoch 227 - Train Loss: 461.9415, Train MRRMSE: 1.1784, Validation Loss: 472.0515, Validation MRRMSE: 1.1011
# Epoch 228 - Train Loss: 469.1189, Train MRRMSE: 1.1911, Validation Loss: 470.1081, Validation MRRMSE: 1.0168
# Epoch 229 - Train Loss: 467.9131, Train MRRMSE: 1.1785, Validation Loss: 469.7362, Validation MRRMSE: 1.0227
# Epoch 230 - Train Loss: 464.0036, Train MRRMSE: 1.1790, Validation Loss: 469.3147, Validation MRRMSE: 1.3461
# Epoch 231 - Train Loss: 454.4264, Train MRRMSE: 1.1695, Validation Loss: 467.1272, Validation MRRMSE: 1.0752
# Epoch 232 - Train Loss: 463.9269, Train MRRMSE: 1.1623, Validation Loss: 465.7057, Validation MRRMSE: 0.9815
# Epoch 233 - Train Loss: 457.2608, Train MRRMSE: 1.1763, Validation Loss: 466.9759, Validation MRRMSE: 1.0020
# Epoch 234 - Train Loss: 465.0578, Train MRRMSE: 1.1558, Validation Loss: 466.0576, Validation MRRMSE: 0.9850
# Epoch 235 - Train Loss: 461.7007, Train MRRMSE: 1.1873, Validation Loss: 467.3156, Validation MRRMSE: 1.0038
# Epoch 236 - Train Loss: 459.4915, Train MRRMSE: 1.1249, Validation Loss: 471.0356, Validation MRRMSE: 1.0090
# Epoch 237 - Train Loss: 460.0132, Train MRRMSE: 1.1794, Validation Loss: 475.7333, Validation MRRMSE: 1.0591
# Epoch 238 - Train Loss: 464.9938, Train MRRMSE: 1.1814, Validation Loss: 475.2836, Validation MRRMSE: 1.0263
# Epoch 239 - Train Loss: 471.9194, Train MRRMSE: 1.1801, Validation Loss: 471.3950, Validation MRRMSE: 1.0068
# Epoch 240 - Train Loss: 461.0226, Train MRRMSE: 1.1515, Validation Loss: 470.0915, Validation MRRMSE: 0.9961
# Epoch 241 - Train Loss: 460.4326, Train MRRMSE: 1.1431, Validation Loss: 470.1212, Validation MRRMSE: 0.9754
# Epoch 242 - Train Loss: 463.9220, Train MRRMSE: 1.1794, Validation Loss: 470.5440, Validation MRRMSE: 0.9875
# Epoch 243 - Train Loss: 461.3110, Train MRRMSE: 1.1676, Validation Loss: 471.2881, Validation MRRMSE: 0.9778
# Epoch 244 - Train Loss: 468.7750, Train MRRMSE: 1.1757, Validation Loss: 469.8178, Validation MRRMSE: 1.0156
# Epoch 245 - Train Loss: 459.9315, Train MRRMSE: 1.1473, Validation Loss: 468.4843, Validation MRRMSE: 1.0866
# Epoch 246 - Train Loss: 463.2697, Train MRRMSE: 1.1649, Validation Loss: 470.7384, Validation MRRMSE: 1.0760
# Epoch 247 - Train Loss: 463.3644, Train MRRMSE: 1.1701, Validation Loss: 469.8069, Validation MRRMSE: 1.0466
# Epoch 248 - Train Loss: 459.9561, Train MRRMSE: 1.1848, Validation Loss: 470.5717, Validation MRRMSE: 1.0025
# Epoch 249 - Train Loss: 462.8906, Train MRRMSE: 1.1632, Validation Loss: 470.1914, Validation MRRMSE: 1.0257
# Epoch 250 - Train Loss: 462.4656, Train MRRMSE: 1.2141, Validation Loss: 471.8147, Validation MRRMSE: 0.9829
# Epoch 251 - Train Loss: 462.6225, Train MRRMSE: 1.1826, Validation Loss: 472.9798, Validation MRRMSE: 0.9989
# Epoch 252 - Train Loss: 454.8613, Train MRRMSE: 1.1405, Validation Loss: 473.2334, Validation MRRMSE: 1.0161
# Epoch 253 - Train Loss: 458.5663, Train MRRMSE: 1.1613, Validation Loss: 471.9647, Validation MRRMSE: 0.9735
# Epoch 254 - Train Loss: 467.1770, Train MRRMSE: 1.1810, Validation Loss: 475.3391, Validation MRRMSE: 1.0082
# Epoch 255 - Train Loss: 457.5862, Train MRRMSE: 1.1838, Validation Loss: 473.4633, Validation MRRMSE: 0.9750
# Epoch 256 - Train Loss: 458.0703, Train MRRMSE: 1.2010, Validation Loss: 470.9834, Validation MRRMSE: 0.9961
# Epoch 257 - Train Loss: 458.5184, Train MRRMSE: 1.1540, Validation Loss: 468.2140, Validation MRRMSE: 0.9873
# Epoch 258 - Train Loss: 459.6293, Train MRRMSE: 1.1789, Validation Loss: 469.0261, Validation MRRMSE: 1.0202
# Epoch 259 - Train Loss: 461.2775, Train MRRMSE: 1.1952, Validation Loss: 470.1695, Validation MRRMSE: 1.0213
# Epoch 260 - Train Loss: 463.6038, Train MRRMSE: 1.1643, Validation Loss: 470.5533, Validation MRRMSE: 1.0139
# Epoch 261 - Train Loss: 458.5841, Train MRRMSE: 1.1715, Validation Loss: 469.8706, Validation MRRMSE: 1.0392
# Epoch 262 - Train Loss: 462.2765, Train MRRMSE: 1.1724, Validation Loss: 470.2933, Validation MRRMSE: 1.0001
# Epoch 263 - Train Loss: 458.1085, Train MRRMSE: 1.1752, Validation Loss: 470.0680, Validation MRRMSE: 0.9970
# Epoch 264 - Train Loss: 455.2813, Train MRRMSE: 1.1772, Validation Loss: 471.8343, Validation MRRMSE: 0.9891
# Epoch 265 - Train Loss: 459.4498, Train MRRMSE: 1.1700, Validation Loss: 471.1107, Validation MRRMSE: 0.9446
# Epoch 266 - Train Loss: 459.4109, Train MRRMSE: 1.1885, Validation Loss: 471.4536, Validation MRRMSE: 0.9874
# Epoch 267 - Train Loss: 457.6687, Train MRRMSE: 1.1395, Validation Loss: 469.4944, Validation MRRMSE: 1.0481
# Epoch 268 - Train Loss: 459.7257, Train MRRMSE: 1.1574, Validation Loss: 469.4374, Validation MRRMSE: 1.0299
# Epoch 269 - Train Loss: 463.3476, Train MRRMSE: 1.1644, Validation Loss: 470.6811, Validation MRRMSE: 1.0301
# Epoch 270 - Train Loss: 458.3784, Train MRRMSE: 1.1815, Validation Loss: 474.2715, Validation MRRMSE: 1.0749
# Epoch 271 - Train Loss: 461.8299, Train MRRMSE: 1.1743, Validation Loss: 477.7940, Validation MRRMSE: 1.1175
# Epoch 272 - Train Loss: 453.7216, Train MRRMSE: 1.1870, Validation Loss: 477.6088, Validation MRRMSE: 1.0420
# Epoch 273 - Train Loss: 460.7654, Train MRRMSE: 1.1877, Validation Loss: 474.6290, Validation MRRMSE: 1.0341
# Epoch 274 - Train Loss: 458.7493, Train MRRMSE: 1.2117, Validation Loss: 470.4419, Validation MRRMSE: 1.0275
# Epoch 275 - Train Loss: 464.2659, Train MRRMSE: 1.1712, Validation Loss: 471.5027, Validation MRRMSE: 1.0438
# Epoch 276 - Train Loss: 464.2879, Train MRRMSE: 1.1808, Validation Loss: 471.1320, Validation MRRMSE: 1.0697
# Epoch 277 - Train Loss: 460.8708, Train MRRMSE: 1.1430, Validation Loss: 468.7036, Validation MRRMSE: 1.0559
# Epoch 278 - Train Loss: 463.8967, Train MRRMSE: 1.1713, Validation Loss: 469.5334, Validation MRRMSE: 1.0388
# Epoch 279 - Train Loss: 458.0428, Train MRRMSE: 1.1648, Validation Loss: 472.6042, Validation MRRMSE: 1.0222
# Epoch 280 - Train Loss: 461.5829, Train MRRMSE: 1.2008, Validation Loss: 474.4644, Validation MRRMSE: 1.0149
# Epoch 281 - Train Loss: 461.8179, Train MRRMSE: 1.1520, Validation Loss: 473.6981, Validation MRRMSE: 0.9916
# Epoch 282 - Train Loss: 463.8819, Train MRRMSE: 1.1701, Validation Loss: 470.3336, Validation MRRMSE: 0.9631
# Epoch 283 - Train Loss: 459.3075, Train MRRMSE: 1.1572, Validation Loss: 471.5927, Validation MRRMSE: 1.0543
# Epoch 284 - Train Loss: 461.2245, Train MRRMSE: 1.1676, Validation Loss: 473.8720, Validation MRRMSE: 1.0576
# Epoch 285 - Train Loss: 455.4007, Train MRRMSE: 1.1549, Validation Loss: 474.0187, Validation MRRMSE: 0.9677
# Epoch 286 - Train Loss: 460.4063, Train MRRMSE: 1.1714, Validation Loss: 476.4969, Validation MRRMSE: 1.1927
# Epoch 287 - Train Loss: 464.2435, Train MRRMSE: 1.2043, Validation Loss: 476.8478, Validation MRRMSE: 1.2523
# Epoch 288 - Train Loss: 462.3257, Train MRRMSE: 1.1394, Validation Loss: 473.5616, Validation MRRMSE: 0.9984
# Epoch 289 - Train Loss: 455.8729, Train MRRMSE: 1.2203, Validation Loss: 472.5775, Validation MRRMSE: 0.9749
# Epoch 290 - Train Loss: 461.5205, Train MRRMSE: 1.1625, Validation Loss: 473.7869, Validation MRRMSE: 1.0699
# Epoch 291 - Train Loss: 458.1895, Train MRRMSE: 1.1727, Validation Loss: 472.3976, Validation MRRMSE: 1.0438
# Epoch 292 - Train Loss: 464.5091, Train MRRMSE: 1.2030, Validation Loss: 471.7885, Validation MRRMSE: 1.0343
# Epoch 293 - Train Loss: 459.7187, Train MRRMSE: 1.1930, Validation Loss: 469.3713, Validation MRRMSE: 1.0115
# Epoch 294 - Train Loss: 464.7489, Train MRRMSE: 1.2091, Validation Loss: 471.8409, Validation MRRMSE: 1.0260
# Epoch 295 - Train Loss: 460.4287, Train MRRMSE: 1.1661, Validation Loss: 471.8437, Validation MRRMSE: 0.9965
# Epoch 296 - Train Loss: 455.9037, Train MRRMSE: 1.2091, Validation Loss: 474.0829, Validation MRRMSE: 1.1442
# Epoch 297 - Train Loss: 458.7202, Train MRRMSE: 1.1824, Validation Loss: 474.6841, Validation MRRMSE: 1.0291
# Epoch 298 - Train Loss: 462.8450, Train MRRMSE: 1.1699, Validation Loss: 476.9153, Validation MRRMSE: 1.0028
# Epoch 299 - Train Loss: 459.6819, Train MRRMSE: 1.1992, Validation Loss: 476.3385, Validation MRRMSE: 1.0655
# Epoch 300 - Train Loss: 456.2541, Train MRRMSE: 1.1621, Validation Loss: 475.1286, Validation MRRMSE: 1.0041
# Epoch 301 - Train Loss: 458.7158, Train MRRMSE: 1.1843, Validation Loss: 473.4503, Validation MRRMSE: 1.0009
# Epoch 302 - Train Loss: 458.8864, Train MRRMSE: 1.1660, Validation Loss: 467.3376, Validation MRRMSE: 1.0090
# Epoch 303 - Train Loss: 457.4954, Train MRRMSE: 1.1624, Validation Loss: 468.2603, Validation MRRMSE: 1.0257
# Epoch 304 - Train Loss: 461.2161, Train MRRMSE: 1.1801, Validation Loss: 471.6431, Validation MRRMSE: 1.0512
# Epoch 305 - Train Loss: 456.2137, Train MRRMSE: 1.1982, Validation Loss: 473.4032, Validation MRRMSE: 0.9979
# Epoch 306 - Train Loss: 461.1657, Train MRRMSE: 1.1848, Validation Loss: 471.5083, Validation MRRMSE: 0.9691
# Epoch 307 - Train Loss: 457.5246, Train MRRMSE: 1.1794, Validation Loss: 470.4114, Validation MRRMSE: 0.9727
# Epoch 308 - Train Loss: 453.2279, Train MRRMSE: 1.1886, Validation Loss: 469.7224, Validation MRRMSE: 1.0258
# Epoch 309 - Train Loss: 463.1006, Train MRRMSE: 1.1976, Validation Loss: 469.0629, Validation MRRMSE: 1.0157
# Epoch 310 - Train Loss: 459.1435, Train MRRMSE: 1.2000, Validation Loss: 469.4362, Validation MRRMSE: 0.9845
# Epoch 311 - Train Loss: 456.1094, Train MRRMSE: 1.1706, Validation Loss: 471.1582, Validation MRRMSE: 0.9889
# Epoch 312 - Train Loss: 459.4744, Train MRRMSE: 1.1698, Validation Loss: 471.1668, Validation MRRMSE: 0.9813
# Epoch 313 - Train Loss: 456.3094, Train MRRMSE: 1.1243, Validation Loss: 470.5535, Validation MRRMSE: 0.9632
# Epoch 314 - Train Loss: 461.7655, Train MRRMSE: 1.1719, Validation Loss: 467.6766, Validation MRRMSE: 0.9654
# Epoch 315 - Train Loss: 462.7024, Train MRRMSE: 1.1565, Validation Loss: 467.3281, Validation MRRMSE: 0.9723
# Epoch 316 - Train Loss: 457.9337, Train MRRMSE: 1.1628, Validation Loss: 467.6427, Validation MRRMSE: 1.0122
# Epoch 317 - Train Loss: 458.7706, Train MRRMSE: 1.1744, Validation Loss: 467.9441, Validation MRRMSE: 1.0427
# Epoch 318 - Train Loss: 457.7292, Train MRRMSE: 1.1887, Validation Loss: 467.2870, Validation MRRMSE: 1.0095
# Epoch 319 - Train Loss: 453.0800, Train MRRMSE: 1.2095, Validation Loss: 466.8344, Validation MRRMSE: 0.9886
# Epoch 320 - Train Loss: 453.5727, Train MRRMSE: 1.1865, Validation Loss: 467.3487, Validation MRRMSE: 0.9840
# Epoch 321 - Train Loss: 452.6233, Train MRRMSE: 1.1722, Validation Loss: 466.7568, Validation MRRMSE: 1.0000
# Epoch 322 - Train Loss: 461.0781, Train MRRMSE: 1.1809, Validation Loss: 468.4962, Validation MRRMSE: 1.0173
# Epoch 323 - Train Loss: 459.5714, Train MRRMSE: 1.1656, Validation Loss: 469.3374, Validation MRRMSE: 1.0099
# Epoch 324 - Train Loss: 460.8365, Train MRRMSE: 1.2082, Validation Loss: 468.2596, Validation MRRMSE: 1.0102
# Epoch 325 - Train Loss: 463.5256, Train MRRMSE: 1.1895, Validation Loss: 468.2717, Validation MRRMSE: 0.9909
# Epoch 326 - Train Loss: 463.3672, Train MRRMSE: 1.2078, Validation Loss: 469.6432, Validation MRRMSE: 1.0010
# Epoch 327 - Train Loss: 458.7974, Train MRRMSE: 1.1531, Validation Loss: 473.2295, Validation MRRMSE: 1.0193
# Epoch 328 - Train Loss: 458.4873, Train MRRMSE: 1.1850, Validation Loss: 475.3128, Validation MRRMSE: 1.0069
# Epoch 329 - Train Loss: 454.6437, Train MRRMSE: 1.1708, Validation Loss: 475.2709, Validation MRRMSE: 0.9790
# Epoch 330 - Train Loss: 458.1635, Train MRRMSE: 1.1630, Validation Loss: 475.1602, Validation MRRMSE: 0.9829
# Epoch 331 - Train Loss: 462.0526, Train MRRMSE: 1.1744, Validation Loss: 474.8762, Validation MRRMSE: 1.0111
# Epoch 332 - Train Loss: 458.4597, Train MRRMSE: 1.2213, Validation Loss: 475.8446, Validation MRRMSE: 1.0167
# Epoch 333 - Train Loss: 458.4025, Train MRRMSE: 1.1851, Validation Loss: 473.9152, Validation MRRMSE: 0.9889
# Epoch 334 - Train Loss: 462.7085, Train MRRMSE: 1.2184, Validation Loss: 471.8743, Validation MRRMSE: 0.9698
# Epoch 335 - Train Loss: 458.8204, Train MRRMSE: 1.1647, Validation Loss: 469.5116, Validation MRRMSE: 0.9539
# Epoch 336 - Train Loss: 462.1363, Train MRRMSE: 1.1994, Validation Loss: 468.6848, Validation MRRMSE: 0.9581
# Epoch 337 - Train Loss: 461.3595, Train MRRMSE: 1.1805, Validation Loss: 466.5884, Validation MRRMSE: 0.9763
# Epoch 338 - Train Loss: 461.4476, Train MRRMSE: 1.1557, Validation Loss: 464.9510, Validation MRRMSE: 0.9981
# Epoch 339 - Train Loss: 465.6615, Train MRRMSE: 1.1770, Validation Loss: 464.9542, Validation MRRMSE: 1.0186
# Epoch 340 - Train Loss: 456.7604, Train MRRMSE: 1.1914, Validation Loss: 465.8689, Validation MRRMSE: 1.0131
# Epoch 341 - Train Loss: 459.4843, Train MRRMSE: 1.2093, Validation Loss: 466.2569, Validation MRRMSE: 0.9965
# Epoch 342 - Train Loss: 452.2028, Train MRRMSE: 1.1628, Validation Loss: 470.8056, Validation MRRMSE: 1.0512
# Epoch 343 - Train Loss: 460.2679, Train MRRMSE: 1.1698, Validation Loss: 471.4448, Validation MRRMSE: 1.0517
# Epoch 344 - Train Loss: 461.6359, Train MRRMSE: 1.2278, Validation Loss: 471.4651, Validation MRRMSE: 1.0886
# Epoch 345 - Train Loss: 460.7149, Train MRRMSE: 1.1849, Validation Loss: 471.1632, Validation MRRMSE: 1.0498
# Epoch 346 - Train Loss: 455.0755, Train MRRMSE: 1.1825, Validation Loss: 471.5960, Validation MRRMSE: 0.9896
# Epoch 347 - Train Loss: 459.4019, Train MRRMSE: 1.2039, Validation Loss: 473.5365, Validation MRRMSE: 0.9579
# Epoch 348 - Train Loss: 465.5227, Train MRRMSE: 1.1570, Validation Loss: 475.1696, Validation MRRMSE: 1.0051
# Epoch 349 - Train Loss: 454.1587, Train MRRMSE: 1.1487, Validation Loss: 474.5068, Validation MRRMSE: 0.9602
# Epoch 350 - Train Loss: 460.8278, Train MRRMSE: 1.1660, Validation Loss: 470.3284, Validation MRRMSE: 0.9392
# Epoch 351 - Train Loss: 462.6552, Train MRRMSE: 1.1814, Validation Loss: 468.4182, Validation MRRMSE: 0.9738
# Epoch 352 - Train Loss: 457.8775, Train MRRMSE: 1.1692, Validation Loss: 470.5257, Validation MRRMSE: 1.0108
# Epoch 353 - Train Loss: 453.6278, Train MRRMSE: 1.1875, Validation Loss: 468.3693, Validation MRRMSE: 1.0437
# Epoch 354 - Train Loss: 463.8729, Train MRRMSE: 1.2121, Validation Loss: 470.1446, Validation MRRMSE: 1.0677
# Epoch 355 - Train Loss: 459.7361, Train MRRMSE: 1.1794, Validation Loss: 475.9875, Validation MRRMSE: 1.0444
# Epoch 356 - Train Loss: 460.2913, Train MRRMSE: 1.2049, Validation Loss: 471.6528, Validation MRRMSE: 1.0013
# Epoch 357 - Train Loss: 462.6883, Train MRRMSE: 1.1954, Validation Loss: 466.1298, Validation MRRMSE: 1.0092
# Epoch 358 - Train Loss: 452.5981, Train MRRMSE: 1.1464, Validation Loss: 466.9969, Validation MRRMSE: 1.0391
# Epoch 359 - Train Loss: 457.6029, Train MRRMSE: 1.1899, Validation Loss: 469.1729, Validation MRRMSE: 1.0081
# Epoch 360 - Train Loss: 457.3439, Train MRRMSE: 1.1578, Validation Loss: 471.0269, Validation MRRMSE: 1.0104
# Epoch 361 - Train Loss: 457.3750, Train MRRMSE: 1.1559, Validation Loss: 472.0269, Validation MRRMSE: 0.9961
# Epoch 362 - Train Loss: 451.5569, Train MRRMSE: 1.2031, Validation Loss: 468.1205, Validation MRRMSE: 0.9558
# Epoch 363 - Train Loss: 463.3166, Train MRRMSE: 1.1920, Validation Loss: 466.4650, Validation MRRMSE: 0.9995
# Epoch 364 - Train Loss: 456.1047, Train MRRMSE: 1.1913, Validation Loss: 465.9622, Validation MRRMSE: 0.9960
# Epoch 365 - Train Loss: 464.6848, Train MRRMSE: 1.1572, Validation Loss: 466.8695, Validation MRRMSE: 0.9949
# Epoch 366 - Train Loss: 457.7333, Train MRRMSE: 1.1679, Validation Loss: 471.8099, Validation MRRMSE: 0.9879
# Epoch 367 - Train Loss: 462.5033, Train MRRMSE: 1.1439, Validation Loss: 474.4780, Validation MRRMSE: 1.0014
# Epoch 368 - Train Loss: 452.9215, Train MRRMSE: 1.1266, Validation Loss: 475.4832, Validation MRRMSE: 0.9728
# Epoch 369 - Train Loss: 456.6320, Train MRRMSE: 1.1463, Validation Loss: 475.4107, Validation MRRMSE: 1.0036
# Epoch 370 - Train Loss: 458.9665, Train MRRMSE: 1.2233, Validation Loss: 474.5487, Validation MRRMSE: 1.0050
# Epoch 371 - Train Loss: 458.3839, Train MRRMSE: 1.1876, Validation Loss: 472.9374, Validation MRRMSE: 1.0250
# Epoch 372 - Train Loss: 458.3951, Train MRRMSE: 1.1557, Validation Loss: 469.0382, Validation MRRMSE: 1.0448
# Epoch 373 - Train Loss: 457.5937, Train MRRMSE: 1.1834, Validation Loss: 466.1481, Validation MRRMSE: 1.0426
# Epoch 374 - Train Loss: 458.0567, Train MRRMSE: 1.1945, Validation Loss: 466.0191, Validation MRRMSE: 0.9838
# Epoch 375 - Train Loss: 454.1764, Train MRRMSE: 1.1714, Validation Loss: 467.4015, Validation MRRMSE: 1.0246
# Epoch 376 - Train Loss: 462.1053, Train MRRMSE: 1.1760, Validation Loss: 469.0303, Validation MRRMSE: 1.0109
# Epoch 377 - Train Loss: 464.2920, Train MRRMSE: 1.1868, Validation Loss: 471.7778, Validation MRRMSE: 0.9949
# Epoch 378 - Train Loss: 457.6460, Train MRRMSE: 1.2145, Validation Loss: 473.3928, Validation MRRMSE: 0.9715
# Epoch 379 - Train Loss: 460.7241, Train MRRMSE: 1.2264, Validation Loss: 473.1103, Validation MRRMSE: 0.9951
# Epoch 380 - Train Loss: 461.1872, Train MRRMSE: 1.1885, Validation Loss: 473.4964, Validation MRRMSE: 0.9736
# Epoch 381 - Train Loss: 458.2671, Train MRRMSE: 1.1523, Validation Loss: 474.9012, Validation MRRMSE: 0.9533
# Epoch 382 - Train Loss: 457.1546, Train MRRMSE: 1.1715, Validation Loss: 474.0535, Validation MRRMSE: 0.9795
# Epoch 383 - Train Loss: 457.2123, Train MRRMSE: 1.1900, Validation Loss: 473.2785, Validation MRRMSE: 0.9842
# Epoch 384 - Train Loss: 460.9622, Train MRRMSE: 1.1778, Validation Loss: 471.9164, Validation MRRMSE: 1.0134
# Epoch 385 - Train Loss: 458.0343, Train MRRMSE: 1.1936, Validation Loss: 469.9035, Validation MRRMSE: 0.9803
# Epoch 386 - Train Loss: 456.7237, Train MRRMSE: 1.1725, Validation Loss: 468.0411, Validation MRRMSE: 1.0152
# Epoch 387 - Train Loss: 457.2936, Train MRRMSE: 1.1550, Validation Loss: 467.0631, Validation MRRMSE: 0.9511
# Epoch 388 - Train Loss: 457.4967, Train MRRMSE: 1.1683, Validation Loss: 469.0627, Validation MRRMSE: 0.9724
# Epoch 389 - Train Loss: 461.4377, Train MRRMSE: 1.2077, Validation Loss: 467.9083, Validation MRRMSE: 0.9693
# Epoch 390 - Train Loss: 459.3906, Train MRRMSE: 1.2199, Validation Loss: 468.3696, Validation MRRMSE: 1.0025
# Epoch 391 - Train Loss: 454.2068, Train MRRMSE: 1.1554, Validation Loss: 469.5286, Validation MRRMSE: 1.0474
# Epoch 392 - Train Loss: 454.1584, Train MRRMSE: 1.2073, Validation Loss: 470.0054, Validation MRRMSE: 1.0398
# Epoch 393 - Train Loss: 454.9725, Train MRRMSE: 1.1372, Validation Loss: 472.5407, Validation MRRMSE: 1.0102
# Epoch 394 - Train Loss: 452.0473, Train MRRMSE: 1.2453, Validation Loss: 471.1563, Validation MRRMSE: 0.9752
# Epoch 395 - Train Loss: 452.7185, Train MRRMSE: 1.1627, Validation Loss: 471.7385, Validation MRRMSE: 1.0380
# Epoch 396 - Train Loss: 459.8836, Train MRRMSE: 1.2087, Validation Loss: 473.0388, Validation MRRMSE: 1.0168
# Epoch 397 - Train Loss: 457.7762, Train MRRMSE: 1.1933, Validation Loss: 472.6912, Validation MRRMSE: 0.9971
# Epoch 398 - Train Loss: 459.2777, Train MRRMSE: 1.1622, Validation Loss: 474.6174, Validation MRRMSE: 1.1125
# Epoch 399 - Train Loss: 456.7362, Train MRRMSE: 1.1527, Validation Loss: 474.7378, Validation MRRMSE: 1.1743
# Epoch 400 - Train Loss: 457.5817, Train MRRMSE: 1.1969, Validation Loss: 470.8889, Validation MRRMSE: 0.9411
# Epoch 401 - Train Loss: 462.5555, Train MRRMSE: 1.1677, Validation Loss: 467.0138, Validation MRRMSE: 0.9763
# Epoch 402 - Train Loss: 457.3581, Train MRRMSE: 1.1593, Validation Loss: 465.7440, Validation MRRMSE: 1.0135
# Epoch 403 - Train Loss: 456.5612, Train MRRMSE: 1.1805, Validation Loss: 465.8972, Validation MRRMSE: 1.0027
# Epoch 404 - Train Loss: 459.9794, Train MRRMSE: 1.1586, Validation Loss: 466.5950, Validation MRRMSE: 0.9963
# Epoch 405 - Train Loss: 453.0264, Train MRRMSE: 1.2003, Validation Loss: 468.7005, Validation MRRMSE: 0.9824
# Epoch 406 - Train Loss: 459.6608, Train MRRMSE: 1.1908, Validation Loss: 470.6553, Validation MRRMSE: 0.9698
# Epoch 407 - Train Loss: 461.3858, Train MRRMSE: 1.1754, Validation Loss: 470.1717, Validation MRRMSE: 1.0037
# Epoch 408 - Train Loss: 453.7640, Train MRRMSE: 1.1802, Validation Loss: 466.5830, Validation MRRMSE: 1.0073
# Epoch 409 - Train Loss: 459.3073, Train MRRMSE: 1.1676, Validation Loss: 468.6419, Validation MRRMSE: 0.9868
# Epoch 410 - Train Loss: 456.0420, Train MRRMSE: 1.2236, Validation Loss: 469.7003, Validation MRRMSE: 0.9680
# Epoch 411 - Train Loss: 459.3650, Train MRRMSE: 1.1536, Validation Loss: 474.2127, Validation MRRMSE: 0.9670
# Epoch 412 - Train Loss: 457.6851, Train MRRMSE: 1.1754, Validation Loss: 474.9553, Validation MRRMSE: 1.0248
# Epoch 413 - Train Loss: 458.4562, Train MRRMSE: 1.2074, Validation Loss: 476.2473, Validation MRRMSE: 0.9977
# Epoch 414 - Train Loss: 451.4666, Train MRRMSE: 1.1442, Validation Loss: 477.1250, Validation MRRMSE: 1.0098
# Epoch 415 - Train Loss: 456.6150, Train MRRMSE: 1.2207, Validation Loss: 474.7654, Validation MRRMSE: 1.0040
# Epoch 416 - Train Loss: 455.9734, Train MRRMSE: 1.1642, Validation Loss: 472.2929, Validation MRRMSE: 1.0493
# Epoch 417 - Train Loss: 452.3945, Train MRRMSE: 1.1564, Validation Loss: 470.3633, Validation MRRMSE: 1.0378
# Epoch 418 - Train Loss: 458.1995, Train MRRMSE: 1.1948, Validation Loss: 469.2477, Validation MRRMSE: 1.0470
# Epoch 419 - Train Loss: 462.2472, Train MRRMSE: 1.1813, Validation Loss: 469.6307, Validation MRRMSE: 1.0427
# Epoch 420 - Train Loss: 461.2961, Train MRRMSE: 1.2086, Validation Loss: 470.3144, Validation MRRMSE: 1.0254
# Epoch 421 - Train Loss: 457.7368, Train MRRMSE: 1.1605, Validation Loss: 469.3057, Validation MRRMSE: 1.0148
# Epoch 422 - Train Loss: 460.9404, Train MRRMSE: 1.1872, Validation Loss: 467.7118, Validation MRRMSE: 0.9905
# Epoch 423 - Train Loss: 456.3413, Train MRRMSE: 1.1910, Validation Loss: 468.5872, Validation MRRMSE: 1.0358
# Epoch 424 - Train Loss: 454.9833, Train MRRMSE: 1.1873, Validation Loss: 469.9967, Validation MRRMSE: 1.1087
# Epoch 425 - Train Loss: 463.1584, Train MRRMSE: 1.2034, Validation Loss: 470.4330, Validation MRRMSE: 1.0368
# Epoch 426 - Train Loss: 454.0679, Train MRRMSE: 1.1621, Validation Loss: 467.7951, Validation MRRMSE: 1.0168
# Epoch 427 - Train Loss: 460.8530, Train MRRMSE: 1.1460, Validation Loss: 465.2858, Validation MRRMSE: 1.0333
# Epoch 428 - Train Loss: 457.5471, Train MRRMSE: 1.1792, Validation Loss: 466.8819, Validation MRRMSE: 0.9965
# Epoch 429 - Train Loss: 453.2290, Train MRRMSE: 1.1649, Validation Loss: 469.1216, Validation MRRMSE: 1.0213
# Epoch 430 - Train Loss: 460.8131, Train MRRMSE: 1.1921, Validation Loss: 471.5139, Validation MRRMSE: 0.9775
# Epoch 431 - Train Loss: 458.5565, Train MRRMSE: 1.2102, Validation Loss: 472.9251, Validation MRRMSE: 0.9609
# Epoch 432 - Train Loss: 461.6295, Train MRRMSE: 1.1699, Validation Loss: 471.7014, Validation MRRMSE: 0.9878
# Epoch 433 - Train Loss: 454.7822, Train MRRMSE: 1.1941, Validation Loss: 469.2035, Validation MRRMSE: 1.0214
# Epoch 434 - Train Loss: 460.5126, Train MRRMSE: 1.1631, Validation Loss: 468.0080, Validation MRRMSE: 1.0451
# Epoch 435 - Train Loss: 458.7461, Train MRRMSE: 1.1556, Validation Loss: 467.4556, Validation MRRMSE: 0.9989
# Epoch 436 - Train Loss: 461.9937, Train MRRMSE: 1.2102, Validation Loss: 467.9208, Validation MRRMSE: 0.9594
# Epoch 437 - Train Loss: 454.2732, Train MRRMSE: 1.1808, Validation Loss: 467.6463, Validation MRRMSE: 1.0206
# Epoch 438 - Train Loss: 458.7168, Train MRRMSE: 1.2461, Validation Loss: 467.8286, Validation MRRMSE: 1.0313
# Epoch 439 - Train Loss: 454.9617, Train MRRMSE: 1.1670, Validation Loss: 467.8546, Validation MRRMSE: 1.0050
# Epoch 440 - Train Loss: 459.0599, Train MRRMSE: 1.1642, Validation Loss: 468.4960, Validation MRRMSE: 0.9676
# ...
# Epoch 855 - Train Loss: 460.9706, Train MRRMSE: 1.1811, Validation Loss: 468.8819, Validation MRRMSE: 0.9577
# Epoch 856 - Train Loss: 456.5741, Train MRRMSE: 1.1862, Validation Loss: 468.8029, Validation MRRMSE: 0.9674
# Epoch 857 - Train Loss: 452.7516, Train MRRMSE: 1.1859, Validation Loss: 468.5799, Validation MRRMSE: 0.9804
# Epoch 858 - Train Loss: 457.9379, Train MRRMSE: 1.1764, Validation Loss: 469.1241, Validation MRRMSE: 0.9801
# Epoch 859 - Train Loss: 464.0326, Train MRRMSE: 1.1654, Validation Loss: 468.8944, Validation MRRMSE: 0.9767
# Epoch 860 - Train Loss: 451.8661, Train MRRMSE: 1.1606, Validation Loss: 468.9259, Validation MRRMSE: 1.0078
# Epoch 861 - Train Loss: 457.0120, Train MRRMSE: 1.1926, Validation Loss: 469.0112, Validation MRRMSE: 0.9547
# Epoch 862 - Train Loss: 457.0121, Train MRRMSE: 1.1840, Validation Loss: 469.6195, Validation MRRMSE: 0.9971
# Epoch 863 - Train Loss: 451.7875, Train MRRMSE: 1.1766, Validation Loss: 469.9906, Validation MRRMSE: 1.0040
# Epoch 864 - Train Loss: 456.4788, Train MRRMSE: 1.1463, Validation Loss: 469.2520, Validation MRRMSE: 0.9572
# Epoch 865 - Train Loss: 454.1037, Train MRRMSE: 1.1604, Validation Loss: 469.1308, Validation MRRMSE: 0.9626
# Epoch 866 - Train Loss: 460.1638, Train MRRMSE: 1.1730, Validation Loss: 469.4601, Validation MRRMSE: 0.9803
# Epoch 867 - Train Loss: 461.8938, Train MRRMSE: 1.1635, Validation Loss: 469.8600, Validation MRRMSE: 1.0171
# Epoch 868 - Train Loss: 451.0189, Train MRRMSE: 1.1791, Validation Loss: 469.5387, Validation MRRMSE: 0.9823
# Epoch 869 - Train Loss: 454.4688, Train MRRMSE: 1.2286, Validation Loss: 469.1351, Validation MRRMSE: 0.9699
# Epoch 870 - Train Loss: 455.2848, Train MRRMSE: 1.1762, Validation Loss: 469.3267, Validation MRRMSE: 0.9635
# Epoch 871 - Train Loss: 456.4291, Train MRRMSE: 1.1615, Validation Loss: 469.1807, Validation MRRMSE: 0.9764
# Epoch 872 - Train Loss: 455.1565, Train MRRMSE: 1.1712, Validation Loss: 469.1319, Validation MRRMSE: 0.9792
# Epoch 873 - Train Loss: 454.5371, Train MRRMSE: 1.1641, Validation Loss: 469.3265, Validation MRRMSE: 0.9765
# Epoch 874 - Train Loss: 452.6893, Train MRRMSE: 1.1574, Validation Loss: 469.3181, Validation MRRMSE: 0.9925
# Epoch 875 - Train Loss: 454.6111, Train MRRMSE: 1.1819, Validation Loss: 469.3394, Validation MRRMSE: 0.9928
# Epoch 876 - Train Loss: 457.4804, Train MRRMSE: 1.1469, Validation Loss: 468.9768, Validation MRRMSE: 0.9662
# Epoch 877 - Train Loss: 451.3690, Train MRRMSE: 1.1881, Validation Loss: 468.7139, Validation MRRMSE: 0.9911
# Epoch 878 - Train Loss: 451.6287, Train MRRMSE: 1.2007, Validation Loss: 468.5445, Validation MRRMSE: 0.9795
# Epoch 879 - Train Loss: 455.2215, Train MRRMSE: 1.1660, Validation Loss: 468.2275, Validation MRRMSE: 0.9955
# Epoch 880 - Train Loss: 458.2946, Train MRRMSE: 1.1851, Validation Loss: 468.8452, Validation MRRMSE: 0.9938
# Epoch 881 - Train Loss: 457.4946, Train MRRMSE: 1.1785, Validation Loss: 469.0229, Validation MRRMSE: 0.9739
# Epoch 882 - Train Loss: 451.4143, Train MRRMSE: 1.1504, Validation Loss: 469.0986, Validation MRRMSE: 1.0118
# Epoch 883 - Train Loss: 462.7395, Train MRRMSE: 1.1528, Validation Loss: 467.8882, Validation MRRMSE: 0.9532
# Epoch 884 - Train Loss: 459.9921, Train MRRMSE: 1.1673, Validation Loss: 468.3400, Validation MRRMSE: 0.9758
# Epoch 885 - Train Loss: 455.8818, Train MRRMSE: 1.1907, Validation Loss: 468.6331, Validation MRRMSE: 0.9703
# Epoch 886 - Train Loss: 453.2980, Train MRRMSE: 1.2035, Validation Loss: 468.5846, Validation MRRMSE: 0.9815
# Epoch 887 - Train Loss: 457.2998, Train MRRMSE: 1.1851, Validation Loss: 468.8181, Validation MRRMSE: 0.9666
# Epoch 888 - Train Loss: 461.8944, Train MRRMSE: 1.1407, Validation Loss: 468.8338, Validation MRRMSE: 0.9939
# Epoch 889 - Train Loss: 455.7011, Train MRRMSE: 1.2054, Validation Loss: 468.7115, Validation MRRMSE: 0.9850
# Epoch 890 - Train Loss: 455.1418, Train MRRMSE: 1.1949, Validation Loss: 468.8293, Validation MRRMSE: 0.9829
# Epoch 891 - Train Loss: 455.0620, Train MRRMSE: 1.1806, Validation Loss: 469.2152, Validation MRRMSE: 0.9701
# Epoch 892 - Train Loss: 452.6285, Train MRRMSE: 1.1716, Validation Loss: 469.1245, Validation MRRMSE: 0.9842
# Epoch 893 - Train Loss: 454.3267, Train MRRMSE: 1.1657, Validation Loss: 469.4842, Validation MRRMSE: 0.9937
# Epoch 894 - Train Loss: 455.9969, Train MRRMSE: 1.1670, Validation Loss: 469.1473, Validation MRRMSE: 0.9819
# Epoch 895 - Train Loss: 449.5662, Train MRRMSE: 1.1609, Validation Loss: 469.5499, Validation MRRMSE: 0.9776
# Epoch 896 - Train Loss: 453.5360, Train MRRMSE: 1.1454, Validation Loss: 469.7591, Validation MRRMSE: 0.9612
# Epoch 897 - Train Loss: 455.6168, Train MRRMSE: 1.1983, Validation Loss: 469.5721, Validation MRRMSE: 0.9763
# Epoch 898 - Train Loss: 457.2800, Train MRRMSE: 1.1388, Validation Loss: 469.3996, Validation MRRMSE: 0.9796
# Epoch 899 - Train Loss: 460.8819, Train MRRMSE: 1.1554, Validation Loss: 468.9049, Validation MRRMSE: 0.9864
# Epoch 900 - Train Loss: 456.4274, Train MRRMSE: 1.1581, Validation Loss: 468.8514, Validation MRRMSE: 1.0004
# Epoch 901 - Train Loss: 458.1018, Train MRRMSE: 1.1651, Validation Loss: 468.5617, Validation MRRMSE: 0.9881
# Epoch 902 - Train Loss: 460.2814, Train MRRMSE: 1.2182, Validation Loss: 469.3148, Validation MRRMSE: 1.0015
# Epoch 903 - Train Loss: 455.5722, Train MRRMSE: 1.1781, Validation Loss: 468.7875, Validation MRRMSE: 0.9917
# Epoch 904 - Train Loss: 457.8549, Train MRRMSE: 1.1572, Validation Loss: 469.2078, Validation MRRMSE: 1.0042
# Epoch 905 - Train Loss: 449.9714, Train MRRMSE: 1.1688, Validation Loss: 468.8417, Validation MRRMSE: 1.0149
# Epoch 906 - Train Loss: 462.3106, Train MRRMSE: 1.2021, Validation Loss: 468.5871, Validation MRRMSE: 0.9922
# Epoch 907 - Train Loss: 457.6998, Train MRRMSE: 1.1610, Validation Loss: 468.4359, Validation MRRMSE: 0.9839
# Epoch 908 - Train Loss: 461.7994, Train MRRMSE: 1.1483, Validation Loss: 468.6309, Validation MRRMSE: 0.9856
# Epoch 909 - Train Loss: 450.3664, Train MRRMSE: 1.2082, Validation Loss: 468.4250, Validation MRRMSE: 0.9979
# Epoch 910 - Train Loss: 460.2753, Train MRRMSE: 1.1992, Validation Loss: 468.2784, Validation MRRMSE: 0.9780
# Epoch 911 - Train Loss: 454.9606, Train MRRMSE: 1.1940, Validation Loss: 469.0025, Validation MRRMSE: 1.0050
# Epoch 912 - Train Loss: 455.3185, Train MRRMSE: 1.1828, Validation Loss: 467.9225, Validation MRRMSE: 0.9687
# Epoch 913 - Train Loss: 460.2076, Train MRRMSE: 1.1846, Validation Loss: 468.6861, Validation MRRMSE: 0.9844
# Epoch 914 - Train Loss: 454.6514, Train MRRMSE: 1.1276, Validation Loss: 469.2883, Validation MRRMSE: 1.0003
# Epoch 915 - Train Loss: 459.8212, Train MRRMSE: 1.1941, Validation Loss: 469.1212, Validation MRRMSE: 0.9975
# Epoch 916 - Train Loss: 452.6434, Train MRRMSE: 1.1780, Validation Loss: 469.5147, Validation MRRMSE: 0.9850
# Epoch 917 - Train Loss: 461.0193, Train MRRMSE: 1.1854, Validation Loss: 469.6894, Validation MRRMSE: 0.9812
# Epoch 918 - Train Loss: 460.4608, Train MRRMSE: 1.1706, Validation Loss: 469.3634, Validation MRRMSE: 0.9798
# Epoch 919 - Train Loss: 453.0347, Train MRRMSE: 1.1370, Validation Loss: 468.9856, Validation MRRMSE: 0.9809
# Epoch 920 - Train Loss: 453.9805, Train MRRMSE: 1.1449, Validation Loss: 469.0174, Validation MRRMSE: 0.9625
# Epoch 921 - Train Loss: 456.9163, Train MRRMSE: 1.1775, Validation Loss: 469.3546, Validation MRRMSE: 0.9965
# Epoch 922 - Train Loss: 459.6933, Train MRRMSE: 1.2078, Validation Loss: 469.2704, Validation MRRMSE: 0.9933
# Epoch 923 - Train Loss: 458.4302, Train MRRMSE: 1.1518, Validation Loss: 469.6303, Validation MRRMSE: 0.9954
# Epoch 924 - Train Loss: 454.1240, Train MRRMSE: 1.1407, Validation Loss: 469.0434, Validation MRRMSE: 0.9796
# Epoch 925 - Train Loss: 454.0820, Train MRRMSE: 1.2079, Validation Loss: 469.5769, Validation MRRMSE: 1.0270
# Epoch 926 - Train Loss: 457.1908, Train MRRMSE: 1.1391, Validation Loss: 469.2462, Validation MRRMSE: 1.0015
# Epoch 927 - Train Loss: 454.4772, Train MRRMSE: 1.1658, Validation Loss: 469.2528, Validation MRRMSE: 0.9727
# Epoch 928 - Train Loss: 454.9191, Train MRRMSE: 1.1734, Validation Loss: 468.9670, Validation MRRMSE: 0.9784
# Epoch 929 - Train Loss: 455.5884, Train MRRMSE: 1.1570, Validation Loss: 469.6048, Validation MRRMSE: 1.0007
# Epoch 930 - Train Loss: 461.2455, Train MRRMSE: 1.2062, Validation Loss: 469.0764, Validation MRRMSE: 0.9639
# Epoch 931 - Train Loss: 460.9029, Train MRRMSE: 1.2107, Validation Loss: 469.6588, Validation MRRMSE: 0.9706
# Epoch 932 - Train Loss: 460.1246, Train MRRMSE: 1.1898, Validation Loss: 469.3169, Validation MRRMSE: 0.9940
# Epoch 933 - Train Loss: 457.9239, Train MRRMSE: 1.1997, Validation Loss: 469.3581, Validation MRRMSE: 0.9678
# Epoch 934 - Train Loss: 453.9548, Train MRRMSE: 1.1716, Validation Loss: 469.5074, Validation MRRMSE: 1.0092
# Epoch 935 - Train Loss: 458.8991, Train MRRMSE: 1.1344, Validation Loss: 469.4465, Validation MRRMSE: 0.9839
# Epoch 936 - Train Loss: 462.9667, Train MRRMSE: 1.1624, Validation Loss: 469.4476, Validation MRRMSE: 0.9789
# Epoch 937 - Train Loss: 448.1113, Train MRRMSE: 1.1635, Validation Loss: 469.0332, Validation MRRMSE: 0.9929
# Epoch 938 - Train Loss: 458.8313, Train MRRMSE: 1.1517, Validation Loss: 468.5591, Validation MRRMSE: 0.9793
# Epoch 939 - Train Loss: 455.1473, Train MRRMSE: 1.1744, Validation Loss: 468.5830, Validation MRRMSE: 0.9691
# Epoch 940 - Train Loss: 455.3395, Train MRRMSE: 1.1550, Validation Loss: 468.4881, Validation MRRMSE: 0.9987
# Epoch 941 - Train Loss: 460.9549, Train MRRMSE: 1.1546, Validation Loss: 469.0999, Validation MRRMSE: 0.9968
# Epoch 942 - Train Loss: 455.5515, Train MRRMSE: 1.1552, Validation Loss: 469.2395, Validation MRRMSE: 0.9724
# Epoch 943 - Train Loss: 450.5152, Train MRRMSE: 1.1510, Validation Loss: 469.0995, Validation MRRMSE: 0.9936
# Epoch 944 - Train Loss: 462.5636, Train MRRMSE: 1.1661, Validation Loss: 468.7241, Validation MRRMSE: 0.9837
# Epoch 945 - Train Loss: 455.4884, Train MRRMSE: 1.2170, Validation Loss: 469.0067, Validation MRRMSE: 1.0034
# Epoch 946 - Train Loss: 450.2881, Train MRRMSE: 1.1501, Validation Loss: 468.4508, Validation MRRMSE: 0.9820
# Epoch 947 - Train Loss: 456.8981, Train MRRMSE: 1.1702, Validation Loss: 469.5914, Validation MRRMSE: 0.9899
# Epoch 948 - Train Loss: 451.0646, Train MRRMSE: 1.2000, Validation Loss: 469.0123, Validation MRRMSE: 0.9631
# Epoch 949 - Train Loss: 454.7045, Train MRRMSE: 1.1638, Validation Loss: 469.6818, Validation MRRMSE: 0.9873
# Epoch 950 - Train Loss: 453.2154, Train MRRMSE: 1.1558, Validation Loss: 469.6260, Validation MRRMSE: 0.9929
# Epoch 951 - Train Loss: 454.4801, Train MRRMSE: 1.1737, Validation Loss: 468.9903, Validation MRRMSE: 0.9727
# Epoch 952 - Train Loss: 457.4546, Train MRRMSE: 1.1553, Validation Loss: 469.2571, Validation MRRMSE: 0.9963
# Epoch 953 - Train Loss: 459.8686, Train MRRMSE: 1.1737, Validation Loss: 469.0707, Validation MRRMSE: 0.9919
# Epoch 954 - Train Loss: 460.0209, Train MRRMSE: 1.1703, Validation Loss: 469.1679, Validation MRRMSE: 0.9605
# Epoch 955 - Train Loss: 452.2524, Train MRRMSE: 1.1181, Validation Loss: 469.5251, Validation MRRMSE: 0.9609
# Epoch 956 - Train Loss: 455.3862, Train MRRMSE: 1.1736, Validation Loss: 468.8705, Validation MRRMSE: 0.9739
# Epoch 957 - Train Loss: 454.3553, Train MRRMSE: 1.1810, Validation Loss: 468.6661, Validation MRRMSE: 0.9799
# Epoch 958 - Train Loss: 452.0996, Train MRRMSE: 1.1589, Validation Loss: 469.1011, Validation MRRMSE: 0.9760
# Epoch 959 - Train Loss: 457.7699, Train MRRMSE: 1.1787, Validation Loss: 469.1707, Validation MRRMSE: 0.9618
# Epoch 960 - Train Loss: 453.2561, Train MRRMSE: 1.2293, Validation Loss: 469.4176, Validation MRRMSE: 0.9826
# Epoch 961 - Train Loss: 459.0035, Train MRRMSE: 1.1764, Validation Loss: 468.6007, Validation MRRMSE: 0.9718
# Epoch 962 - Train Loss: 451.6176, Train MRRMSE: 1.1574, Validation Loss: 468.7513, Validation MRRMSE: 0.9688
# Epoch 963 - Train Loss: 448.0718, Train MRRMSE: 1.1317, Validation Loss: 468.3316, Validation MRRMSE: 0.9918
# Epoch 964 - Train Loss: 459.2441, Train MRRMSE: 1.2036, Validation Loss: 468.7466, Validation MRRMSE: 0.9722
# Epoch 965 - Train Loss: 463.1374, Train MRRMSE: 1.1909, Validation Loss: 469.1507, Validation MRRMSE: 0.9822
# Epoch 966 - Train Loss: 457.4480, Train MRRMSE: 1.1720, Validation Loss: 469.9436, Validation MRRMSE: 0.9929
# Epoch 967 - Train Loss: 464.0782, Train MRRMSE: 1.1906, Validation Loss: 469.5730, Validation MRRMSE: 0.9899
# Epoch 968 - Train Loss: 453.8418, Train MRRMSE: 1.1823, Validation Loss: 469.6601, Validation MRRMSE: 0.9876
# Epoch 969 - Train Loss: 456.6334, Train MRRMSE: 1.1883, Validation Loss: 469.2324, Validation MRRMSE: 0.9743
# Epoch 970 - Train Loss: 461.1297, Train MRRMSE: 1.1744, Validation Loss: 469.3769, Validation MRRMSE: 0.9782
# Epoch 971 - Train Loss: 451.3544, Train MRRMSE: 1.1500, Validation Loss: 469.4091, Validation MRRMSE: 0.9766
# Epoch 972 - Train Loss: 457.3585, Train MRRMSE: 1.1600, Validation Loss: 469.2316, Validation MRRMSE: 0.9839
# Epoch 973 - Train Loss: 455.8361, Train MRRMSE: 1.1866, Validation Loss: 469.4530, Validation MRRMSE: 0.9858
# Epoch 974 - Train Loss: 454.2278, Train MRRMSE: 1.1279, Validation Loss: 469.2237, Validation MRRMSE: 0.9818
# Epoch 975 - Train Loss: 459.5208, Train MRRMSE: 1.1599, Validation Loss: 468.7932, Validation MRRMSE: 0.9935
# Epoch 976 - Train Loss: 458.8404, Train MRRMSE: 1.1518, Validation Loss: 468.5146, Validation MRRMSE: 1.0120
# Epoch 977 - Train Loss: 451.0788, Train MRRMSE: 1.1909, Validation Loss: 468.7043, Validation MRRMSE: 1.0068
# Epoch 978 - Train Loss: 455.7169, Train MRRMSE: 1.1495, Validation Loss: 468.7366, Validation MRRMSE: 0.9964
# Epoch 979 - Train Loss: 455.0130, Train MRRMSE: 1.1741, Validation Loss: 469.3375, Validation MRRMSE: 1.0034
# Epoch 980 - Train Loss: 464.2039, Train MRRMSE: 1.1941, Validation Loss: 468.9374, Validation MRRMSE: 0.9806
# Epoch 981 - Train Loss: 453.0068, Train MRRMSE: 1.1421, Validation Loss: 469.1310, Validation MRRMSE: 1.0057
# Epoch 982 - Train Loss: 454.9430, Train MRRMSE: 1.1634, Validation Loss: 468.6768, Validation MRRMSE: 0.9764
# Epoch 983 - Train Loss: 453.9847, Train MRRMSE: 1.1550, Validation Loss: 468.4787, Validation MRRMSE: 0.9752
# Epoch 00983: reducing learning rate of group 0 to 1.0000e-07.
# Epoch 984 - Train Loss: 457.1118, Train MRRMSE: 1.1998, Validation Loss: 468.9652, Validation MRRMSE: 0.9869
# Epoch 985 - Train Loss: 451.7743, Train MRRMSE: 1.1530, Validation Loss: 469.4479, Validation MRRMSE: 0.9904
# Epoch 986 - Train Loss: 460.5244, Train MRRMSE: 1.2028, Validation Loss: 469.4958, Validation MRRMSE: 0.9923
# Epoch 987 - Train Loss: 454.7621, Train MRRMSE: 1.1581, Validation Loss: 469.7074, Validation MRRMSE: 0.9841
# Epoch 988 - Train Loss: 455.1654, Train MRRMSE: 1.1127, Validation Loss: 469.4050, Validation MRRMSE: 0.9800
# Epoch 989 - Train Loss: 459.2014, Train MRRMSE: 1.1955, Validation Loss: 468.7911, Validation MRRMSE: 1.0049
# Epoch 990 - Train Loss: 457.9492, Train MRRMSE: 1.1862, Validation Loss: 469.2455, Validation MRRMSE: 1.0129
# Epoch 991 - Train Loss: 463.2473, Train MRRMSE: 1.1447, Validation Loss: 468.5121, Validation MRRMSE: 1.0026
# Epoch 992 - Train Loss: 455.2610, Train MRRMSE: 1.1442, Validation Loss: 469.1370, Validation MRRMSE: 1.0031
# Epoch 993 - Train Loss: 456.0992, Train MRRMSE: 1.1325, Validation Loss: 468.3294, Validation MRRMSE: 0.9898
# Epoch 994 - Train Loss: 456.4089, Train MRRMSE: 1.1860, Validation Loss: 468.6869, Validation MRRMSE: 0.9838
# Epoch 995 - Train Loss: 456.6074, Train MRRMSE: 1.1437, Validation Loss: 469.2145, Validation MRRMSE: 0.9892
# Epoch 996 - Train Loss: 457.7978, Train MRRMSE: 1.1388, Validation Loss: 468.9904, Validation MRRMSE: 0.9800
# Epoch 997 - Train Loss: 460.0234, Train MRRMSE: 1.1900, Validation Loss: 469.0032, Validation MRRMSE: 0.9848
# Epoch 998 - Train Loss: 453.7790, Train MRRMSE: 1.1785, Validation Loss: 468.6857, Validation MRRMSE: 0.9632
# Epoch 999 - Train Loss: 453.5860, Train MRRMSE: 1.2038, Validation Loss: 469.6149, Validation MRRMSE: 0.9795
# Epoch 1000 - Train Loss: 454.6502, Train MRRMSE: 1.1587, Validation Loss: 469.6979, Validation MRRMSE: 0.9772

# %% [markdown]
# ## Test Evaluation

# %%
from sympy import true


test_path = r"..\data\data_test.parquet"  # Path to the test dataset
test_dataset = ParquetDataset(test_path)
test_dataloader = DataLoader(test_dataset, batch_size=256, shuffle=False)


def predict_with_vae(model, dataloader, device):
    model.eval()
    predictions = []
    with torch.no_grad():
        for batch_x in dataloader:
            _, data = batch_x
            data = data.to(device)
            reconstructed_data = model.decode(data)

            predictions.append(reconstructed_data.cpu().numpy())

    return np.concatenate(predictions, axis=0)


# Load the true values for the test dataset
true_values = [data.numpy() for data, _ in test_dataloader]
true_values = np.array(true_values).squeeze(0)
print(true_values.shape)

# Make predictions
predictions = predict_with_vae(vae_model, test_dataloader, device)
print(predictions.shape)
# Calculate metrics
metric_result = mean_rowwise_rmse(
    torch.from_numpy(predictions), torch.from_numpy(true_values)
)
print({metric_result})
# Out:
# (71, 7818)
# (71, 7818)
# {tensor(4.9415)}
